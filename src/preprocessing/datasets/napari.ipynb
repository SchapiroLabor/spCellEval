# %%
import tifffile
import numpy as np
import napari
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
img = tifffile.imread('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_codex/image/reg001_montage.tif')

# %%
img.shape

# %%
img_0 = img[:, 0, :, :]
img_1 = img[:, 1, :, :]
img_2 = img[:, 2, :, :]
img_3 = img[:, 3, :, :]

# %%
viewer = napari.Viewer()
viewer.add_image(img_0, name='channel 0', channel_axis=0)

# %%
viewer.add_image(img_1, name='channel 1', channel_axis=0)

# %%
viewer.add_image(img_2, name='channel 2', channel_axis=0)

# %%
viewer.add_image(img_3, name='channel 3', channel_axis=0)
