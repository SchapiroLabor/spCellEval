# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results = np.load('/Volumes/Lukas_SSD/phenotyping_benchmark/stellar_test/experiments/STELLAR_run/Hubmap_STELLAR/Hubmap_results.npy')

# %%
pred = np.load('/Volumes/Lukas_SSD/phenotyping_benchmark/stellar_test/experiments/test_B004/B004_head22.npy')

# %%
pred
# Out:
# array([6, 6, 6, ..., 6, 6, 6])

# %%
pred = np.load('/Volumes/Lukas_SSD/phenotyping_benchmark/stellar_test/experiments/test_B004/B004_head21.npy')

# %%
pred
# Out:
# array([6, 6, 6, ..., 6, 6, 6])

# %%
annot = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/stellar_test/B004_training_dryad_2.csv')
pred = np.load('/Volumes/Lukas_SSD/phenotyping_benchmark/stellar_test/experiments/test_B004/B004_head22.npy')
training = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/stellar_test/B004_training_dryad_1.csv')
unannotated = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/stellar_test/B004_training_dryad_2_unannotated.csv')

# %%
training[training['unique_region'].str.contains('CL')]
# Out:
#             MUC2      SOX9      MUC1      CD31   Synapto     CD49f      CD15  \
# 0      -0.304219 -0.598730 -0.582675 -0.213334 -0.266697 -0.647282 -0.299032
# 3      -0.139185  0.068790  0.969542 -0.235546 -0.020454 -0.137180  0.529629
# 5      -0.302814  0.078137 -0.272089 -0.224140  0.290917  0.298251  1.379774
# 6      -0.298575 -0.492954 -0.466558 -0.244170 -0.240861  1.606057 -0.281509
# 10     -0.246054  0.002277 -0.005785 -0.241872  0.136911  0.563520  1.409783
# ...          ...       ...       ...       ...       ...       ...       ...
# 186198  1.048634  0.296961 -0.279768 -0.242026 -0.217951 -0.634026 -0.299028
# 186202 -0.304218 -0.495008 -0.204715 -0.233478  2.153044 -0.301036 -0.094774
# 186203  2.286351  3.499340  4.696901 -0.237243  0.402160  0.984894  0.743122
# 186206 -0.303278 -0.102658 -0.488201  1.375266 -0.229042  0.682580 -0.284618
# 186211 -0.304218  0.003909  1.522633 -0.238637  0.394558  1.113966  0.688243
#
# ...

# %%
unannotated[unannotated['unique_region'].str.contains('CL')]
# Out:
#            MUC2      SOX9      MUC1      CD31   Synapto     CD49f      CD15  \
# 3     -0.304218 -0.441068 -0.488364 -0.245246 -0.249533 -0.655897 -0.296514
# 5     -0.304218 -0.248985 -0.366759 -0.244859 -0.264027 -0.651511 -0.299031
# 6     -0.304219 -0.567890 -0.395715 -0.179433 -0.251982  0.265660 -0.288375
# 7     -0.262812 -0.397274 -0.507311 -0.186925  0.103533 -0.663029 -0.278434
# 9     -0.304218 -0.615592 -0.569891 -0.240010 -0.266698 -0.625551 -0.299030
# ...         ...       ...       ...       ...       ...       ...       ...
# 62065 -0.298560  0.642043 -0.455926 -0.236873 -0.254540 -0.554392 -0.299030
# 62066 -0.304218 -0.487215 -0.307002 -0.221246 -0.236888  2.991329  0.388138
# 62067  0.103583  3.705640  0.619619 -0.243033 -0.036856  1.185025 -0.285600
# 62068  0.279789 -0.027508 -0.383640 -0.234653  0.836268 -0.568663 -0.299031
# 62071 -0.302229 -0.284368 -0.248169 -0.237995 -0.263219 -0.534770 -0.299033
#
# ...

# %%
annot[annot['unique_region'].str.contains('CL')]
# Out:
#            MUC2      SOX9      MUC1      CD31   Synapto     CD49f      CD15  \
# 3     -0.304218 -0.441068 -0.488364 -0.245246 -0.249533 -0.655897 -0.296514
# 5     -0.304218 -0.248985 -0.366759 -0.244859 -0.264027 -0.651511 -0.299031
# 6     -0.304219 -0.567890 -0.395715 -0.179433 -0.251982  0.265660 -0.288375
# 7     -0.262812 -0.397274 -0.507311 -0.186925  0.103533 -0.663029 -0.278434
# 9     -0.304218 -0.615592 -0.569891 -0.240010 -0.266698 -0.625551 -0.299030
# ...         ...       ...       ...       ...       ...       ...       ...
# 62065 -0.298560  0.642043 -0.455926 -0.236873 -0.254540 -0.554392 -0.299030
# 62066 -0.304218 -0.487215 -0.307002 -0.221246 -0.236888  2.991329  0.388138
# 62067  0.103583  3.705640  0.619619 -0.243033 -0.036856  1.185025 -0.285600
# 62068  0.279789 -0.027508 -0.383640 -0.234653  0.836268 -0.568663 -0.299031
# 62071 -0.302229 -0.284368 -0.248169 -0.237995 -0.263219 -0.534770 -0.299033
#
# ...

# %%
len(annot['cell_type_A'].unique())
# Out:
# 21

# %%
training
# Out:
#             MUC2      SOX9      MUC1      CD31   Synapto     CD49f      CD15  \
# 0      -0.304219 -0.598730 -0.582675 -0.213334 -0.266697 -0.647282 -0.299032
# 1      -0.241565  0.389984  0.043845 -0.140651 -0.276790 -0.392779 -0.094144
# 2      -0.241565 -0.456762 -0.187430 -0.149993 -0.164611 -0.439395 -0.094143
# 3      -0.139185  0.068790  0.969542 -0.235546 -0.020454 -0.137180  0.529629
# 4      -0.241566 -0.440694 -0.275723 -0.248366 -0.138385 -0.584089 -0.088861
# ...          ...       ...       ...       ...       ...       ...       ...
# 186208 -0.232050 -0.426096 -0.274248  0.830014 -0.330975 -0.485997 -0.094141
# 186209  0.397264  3.448154  0.277018 -0.247519 -0.124134  0.933174 -0.094143
# 186210 -0.241565 -0.036779 -0.138739 -0.256127  4.735035 -0.494155 -0.094145
# 186211 -0.304218  0.003909  1.522633 -0.238637  0.394558  1.113966  0.688243
# 186212 -0.236816 -0.481441 -0.118968 -0.256136 -0.333212 -0.577522  0.038033
#
# ...

# %%
len(training['cell_type_A'].unique())
# Out:
# 21

# %%
unique_values = np.unique(pred)
print(unique_values)
# Out:
# [6]
