# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
result_data = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/results/cHL_2_MIBI/TACIT/level3/nonscaled/predictions_2.csv')

# %%
cr = classification_report(result_data['true_phenotype'], result_data['predicted_phenotype'])
print(cr)
# Out:
#                 precision    recall  f1-score   support
#
#         B_cell       0.79      0.62      0.69     24129
#    CD4+_T_cell       0.50      0.43      0.46     54832
#    CD8+_T_cell       0.24      0.28      0.26     13120
#         Cancer       0.41      0.34      0.37      7102
# Dendritic_cell       0.29      0.37      0.33     19824
#    Endothelial       0.72      0.81      0.76      5809
#  M1_Macrophage       0.25      0.45      0.32      4909
#  M2_Macrophage       0.42      0.80      0.55     23726
#        NK_cell       0.95      0.15      0.26      4885
#     Neutrophil       0.74      0.72      0.73     16833
#           Treg       0.83      0.31      0.45     39962
#      undefined       0.37      0.60      0.46     15758
#
#       accuracy                           0.49    230889
#      macro avg       0.54      0.49      0.47    230889
#   weighted avg       0.56      0.49      0.49    230889

# %%
cm = confusion_matrix(result_data['true_phenotype'], result_data['predicted_phenotype'])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(result_data['true_phenotype']))
disp.plot(cmap='Blues', xticks_rotation=90)

# %%
result_data = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/results/cHL_2_MIBI/TACIT/level3/predictions_1_r20_p10.csv')
cr = classification_report(result_data['true_phenotype'], result_data['predicted_phenotype'])
print(cr)
# Out:
#                 precision    recall  f1-score   support
#
#         B_cell       0.79      0.63      0.70     24129
#    CD4+_T_cell       0.72      0.06      0.11     54832
#    CD8+_T_cell       0.15      0.47      0.22     13120
#         Cancer       0.58      0.26      0.36      7102
# Dendritic_cell       0.32      0.37      0.34     19824
#    Endothelial       0.73      0.84      0.78      5809
#  M1_Macrophage       0.25      0.48      0.33      4909
#  M2_Macrophage       0.41      0.80      0.55     23726
#        NK_cell       0.89      0.15      0.26      4885
#     Neutrophil       0.74      0.72      0.73     16833
#           Treg       0.51      0.45      0.48     39962
#      undefined       0.40      0.64      0.49     15758
#
#       accuracy                           0.44    230889
#      macro avg       0.54      0.49      0.45    230889
#   weighted avg       0.56      0.44      0.41    230889

# %%
result_data = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/results/cHL_2_MIBI/TACIT/level3/predictions_1_r5_p10.csv')
cr = classification_report(result_data['true_phenotype'], result_data['predicted_phenotype'])
print(cr)
# Out:
#                 precision    recall  f1-score   support
#
#         B_cell       0.77      0.63      0.70     24129
#    CD4+_T_cell       0.66      0.09      0.16     54832
#    CD8+_T_cell       0.17      0.43      0.24     13120
#         Cancer       0.55      0.23      0.33      7102
# Dendritic_cell       0.31      0.39      0.35     19824
#    Endothelial       0.74      0.82      0.77      5809
#  M1_Macrophage       0.25      0.46      0.32      4909
#  M2_Macrophage       0.41      0.80      0.54     23726
#        NK_cell       0.95      0.15      0.26      4885
#     Neutrophil       0.74      0.72      0.73     16833
#           Treg       0.51      0.48      0.50     39962
#      undefined       0.38      0.62      0.47     15758
#
#       accuracy                           0.45    230889
#      macro avg       0.54      0.49      0.45    230889
#   weighted avg       0.55      0.45      0.42    230889

# %%
result_data = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/results/cHL_2_MIBI/TACIT/level3/predictions_1_r10_p5.csv')
cr = classification_report(result_data['true_phenotype'], result_data['predicted_phenotype'])
print(cr)
# Out:
#                 precision    recall  f1-score   support
#
#         B_cell       0.79      0.61      0.69     24129
#    CD4+_T_cell       0.75      0.09      0.16     54832
#    CD8+_T_cell       0.15      0.47      0.22     13120
#         Cancer       0.56      0.29      0.38      7102
# Dendritic_cell       0.31      0.41      0.35     19824
#    Endothelial       0.72      0.82      0.77      5809
#  M1_Macrophage       0.25      0.45      0.32      4909
#  M2_Macrophage       0.41      0.80      0.54     23726
#        NK_cell       0.94      0.14      0.24      4885
#     Neutrophil       0.74      0.72      0.73     16833
#           Treg       0.53      0.41      0.46     39962
#      undefined       0.40      0.62      0.48     15758
#
#       accuracy                           0.44    230889
#      macro avg       0.55      0.48      0.45    230889
#   weighted avg       0.57      0.44      0.42    230889

# %%
result_data = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/results/cHL_2_MIBI/TACIT/level3/predictions_1_r15_p5.csv')
cr = classification_report(result_data['true_phenotype'], result_data['predicted_phenotype'])
print(cr)
# Out:
#                 precision    recall  f1-score   support
#
#         B_cell       0.78      0.64      0.70     24129
#    CD4+_T_cell       0.73      0.09      0.17     54832
#    CD8+_T_cell       0.18      0.41      0.25     13120
#         Cancer       0.56      0.26      0.35      7102
# Dendritic_cell       0.31      0.39      0.34     19824
#    Endothelial       0.71      0.82      0.76      5809
#  M1_Macrophage       0.25      0.47      0.33      4909
#  M2_Macrophage       0.40      0.82      0.54     23726
#        NK_cell       0.92      0.14      0.25      4885
#     Neutrophil       0.74      0.71      0.72     16833
#           Treg       0.52      0.49      0.51     39962
#      undefined       0.37      0.60      0.46     15758
#
#       accuracy                           0.45    230889
#      macro avg       0.54      0.49      0.45    230889
#   weighted avg       0.56      0.45      0.43    230889

# %%
result_data = pd.read_csv('/Users/lukashat/Documents/PhD_Schapiro/Projects/phenotype_benchmark/results/cHL_2_MIBI/TACIT/level3/predictions_1_r5_p5.csv')
cr = classification_report(result_data['true_phenotype'], result_data['predicted_phenotype'])
print(cr)
# Out:
#                 precision    recall  f1-score   support
#
#         B_cell       0.76      0.65      0.70     24129
#    CD4+_T_cell       0.75      0.04      0.08     54832
#    CD8+_T_cell       0.15      0.44      0.23     13120
#         Cancer       0.59      0.20      0.30      7102
# Dendritic_cell       0.31      0.38      0.34     19824
#    Endothelial       0.73      0.81      0.77      5809
#  M1_Macrophage       0.25      0.46      0.32      4909
#  M2_Macrophage       0.40      0.82      0.54     23726
#        NK_cell       0.92      0.14      0.24      4885
#     Neutrophil       0.73      0.72      0.73     16833
#           Treg       0.50      0.49      0.49     39962
#      undefined       0.41      0.59      0.48     15758
#
#       accuracy                           0.44    230889
#      macro avg       0.54      0.48      0.43    230889
#   weighted avg       0.56      0.44      0.40    230889

# %%
result_data.columns
# Out:
# Index(['MPO', 'HistoneH3', 'SMA', 'CD16', 'CD38', 'HLADR', 'CD27', 'CD15',
#        'CD45RA', 'CD163', 'B2M', 'CD20', 'CD68', 'Ido1', 'CD3', 'LAG3',
#        'CD11c', 'PD1', 'PDGFRb', 'CD7', 'GrzB', 'PDL1', 'TCF7', 'CD45RO',
#        'FOXP3', 'ICOS', 'CD8a', 'CarbonicAnhydrase', 'CD33', 'Ki67', 'VISTA',
#        'CD40', 'CD4', 'CD14', 'Ecad', 'CD303', 'CD206', 'cleavedPARP', 'DNA1',
#        'DNA2', 'image', 'sample_id', 'cell_id', 'x', 'y', 'area',
#        'major_axis_length', 'minor_axis_length', 'eccentricity', 'width_px',
#        'height_px', 'cell_labels', 'level_1_cell_type', 'level_2_cell_type',
#        'true_phenotype', 'predicted_phenotype'],
#       dtype='object')
