# %%
from logistic_regression import MultinomialLogisticRegression
import pandas as pd

# %%
cHL2 = MultinomialLogisticRegression(random_state = 42, penalty='elasticnet', n_jobs=-1, l1_ratio=0.5, max_iter=5000)

# %%
cHL2.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/kfolds')

# %%
cHL2.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/labels.csv')

# %%
cHL1 = MultinomialLogisticRegression(random_state = 42, penalty='elasticnet', n_jobs=-1, l1_ratio=0.5, max_iter=5000)
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 42
#   Max Iterations: 5000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: elasticnet
#   L1 Ratio: 0.5
#   Solver: saga
#   Number of Jobs: -1

# %%
cHL1.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/kfolds')
# Out:
# {'train': ['fold_1_train.csv', 'fold_2_train.csv', 'fold_3_train.csv', 'fold_4_train.csv', 'fold_5_train.csv'], 'test': ['fold_1_test.csv', 'fold_2_test.csv', 'fold_3_test.csv', 'fold_4_test.csv', 'fold_5_test.csv']}
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.6202726810445236
# Recall: 0.653124113168902
# Accuracy: 0.653124113168902
# F1 Score: 0.48076629697245965
# Weighted F1 Score: 0.6115873165361542
# ==================================================
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.6181130926680499
# Recall: 0.6489543757247892
# Accuracy: 0.6489543757247892
# F1 Score: 0.5058244719097318
# Weighted F1 Score: 0.6106412380449157
# ==================================================
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.6294144756711427
# Recall: 0.6299925154793495
# Accuracy: 0.6299925154793495
# F1 Score: 0.49476012092084803
# Weighted F1 Score: 0.5939096584645683
# ==================================================
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.6080845124113411
# Recall: 0.6313603637741568
# Accuracy: 0.6313603637741568
# F1 Score: 0.4927196604734352
# Weighted F1 Score: 0.5900422078621147
# ==================================================
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.6257937554129854
# Recall: 0.6450268943486634
# Accuracy: 0.6450268943486634
# F1 Score: 0.5168099333448597
# Weighted F1 Score: 0.6119643964883487
# ==================================================
# Average Accuracy across all folds: 0.6416916524991721
# Average F1 Score across all folds: 0.4981760967242669
# Average Weighted F1 Score across all folds: 0.6036289634792202
# Average Precision across all folds: 0.6203357034416086
# Average Recall across all folds: 0.6416916524991721

# %%
cHL1.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/results_logreg.

# %%
cHL_CODEX = MultinomialLogisticRegression(random_state = 42, penalty='elasticnet', n_jobs=-1, l1_ratio=0.5, max_iter=5000)
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 42
#   Max Iterations: 5000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: elasticnet
#   L1 Ratio: 0.5
#   Solver: saga
#   Number of Jobs: -1

# %%
cHL_CODEX.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/kfolds')
# Out:
# {'train': ['fold_1_train.csv', 'fold_2_train.csv', 'fold_3_train.csv', 'fold_4_train.csv', 'fold_5_train.csv'], 'test': ['fold_1_test.csv', 'fold_2_test.csv', 'fold_3_test.csv', 'fold_4_test.csv', 'fold_5_test.csv']}
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.7950905832614765
# Recall: 0.7938147916231824
# Accuracy: 0.7938147916231824
# F1 Score: 0.759342352744918
# Weighted F1 Score: 0.7927549611431954
# ==================================================
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.7934192830125193
# Recall: 0.7926668058164614
# Accuracy: 0.7926668058164614
# F1 Score: 0.7651591518191178
# Weighted F1 Score: 0.7917909014358729
# ==================================================
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.7915298889172603
# Recall: 0.7915883949071175
# Accuracy: 0.7915883949071175
# F1 Score: 0.7636176217157306
# Weighted F1 Score: 0.7897319468269247
# ==================================================
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.7896981524282978
# Recall: 0.7875878383079385
# Accuracy: 0.7875878383079385
# F1 Score: 0.7545296807628179
# Weighted F1 Score: 0.7874066620896963
# ==================================================
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.7920651951909955
# Recall: 0.7909970082794128
# Accuracy: 0.7909970082794128
# F1 Score: 0.7606660181087939
# Weighted F1 Score: 0.7903634441600309
# ==================================================
# Average Accuracy across all folds: 0.7913309677868224
# Average F1 Score across all folds: 0.7606629650302755
# Average Weighted F1 Score across all folds: 0.7904095831311441
# Average Precision across all folds: 0.7923606205621099
# Average Recall across all folds: 0.7913309677868224

# %%
cHL_CODEX.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/results_logreg.
