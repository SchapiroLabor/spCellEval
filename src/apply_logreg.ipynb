# %%
from logistic_regression import MultinomialLogisticRegression
import pandas as pd

# %%
rs = 20240925

# %%
cHL2 = MultinomialLogisticRegression(random_state = rs, n_jobs=-1, max_iter=1000)
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None

# %%
cHL2.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/kfolds')
# Out:
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.7514492861542337
# Recall: 0.74130538351596
# Accuracy: 0.74130538351596
# F1 Score: 0.7082500517739257
# Weighted F1 Score: 0.7373309250636013
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.7491735511235771
# Recall: 0.739616267486682
# Accuracy: 0.739616267486682
# F1 Score: 0.7058190159638361
# Weighted F1 Score: 0.7356611363700807
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.7543599869904571
# Recall: 0.7465459742734636
# Accuracy: 0.7465459742734636
# F1 Score: 0.712028700505015
# Weighted F1 Score: 0.7420971804816315
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.7525891137572204
# Recall: 0.7438607128935857
# Accuracy: 0.7438607128935857
# F1 Score: 0.7101289295800237
# Weighted F1 Score: 0.7398913833066696
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.7527117423429635
# Recall: 0.7429456222794898
# Accuracy: 0.7429456222794898
# F1 Score: 0.7083818503847122
# Weighted F1 Score: 0.7390274892751305
# ==================================================
# Average Accuracy across all folds: 0.7428547920898362
# Average F1 Score across all folds: 0.7089217096415025
# Average Weighted F1 Score across all folds: 0.7388016228994226
# Average Precision across all folds: 0.7520567360736903
# Average Recall across all folds: 0.7428547920898362

# %%
cHL2.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/results_logreg.

# %%
cHL1 = MultinomialLogisticRegression(random_state = rs, n_jobs=-1, max_iter=1000)
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None

# %%
cHL1.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/kfolds')
# Out:
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.7149224249043424
# Recall: 0.7208709738270688
# Accuracy: 0.7208709738270688
# F1 Score: 0.6597825195495016
# Weighted F1 Score: 0.7084181763983919
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.7147937495300268
# Recall: 0.7209637962577589
# Accuracy: 0.7209637962577589
# F1 Score: 0.6596207009509126
# Weighted F1 Score: 0.7082758859799111
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.7155440836098644
# Recall: 0.7211883666545897
# Accuracy: 0.7211883666545897
# F1 Score: 0.6613113681373679
# Weighted F1 Score: 0.7090534545462309
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.7146564755478964
# Recall: 0.720968949306824
# Accuracy: 0.720968949306824
# F1 Score: 0.6586184808268886
# Weighted F1 Score: 0.7083323305928132
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.7149817832691421
# Recall: 0.7204838757972273
# Accuracy: 0.7204838757972273
# F1 Score: 0.6619724030972731
# Weighted F1 Score: 0.7081320561877594
# ==================================================
# Average Accuracy across all folds: 0.7208951923686937
# Average F1 Score across all folds: 0.6602610945123887
# Average Weighted F1 Score across all folds: 0.7084423807410213
# Average Precision across all folds: 0.7149797033722545
# Average Recall across all folds: 0.7208951923686937

# %%
cHL1.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/results_logreg.

# %%
cHL_CODEX = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)#, class_weight='balanced')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None

# %%
cHL_CODEX.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/kfolds')
# Out:
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.7955105193341943
# Recall: 0.7957628887497391
# Accuracy: 0.7957628887497391
# F1 Score: 0.7752487306729579
# Weighted F1 Score: 0.7942008094887314
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.7982236627739899
# Recall: 0.7985806720935087
# Accuracy: 0.7985806720935087
# F1 Score: 0.7771068519477652
# Weighted F1 Score: 0.7970253826429373
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.7945865137067144
# Recall: 0.7951367146733459
# Accuracy: 0.7951367146733459
# F1 Score: 0.7731653197033744
# Weighted F1 Score: 0.7936966496633665
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.7975008564803899
# Recall: 0.7972239615946567
# Accuracy: 0.7972239615946567
# F1 Score: 0.7737502107636224
# Weighted F1 Score: 0.7959565256800638
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.7971751815838577
# Recall: 0.796841299659083
# Accuracy: 0.796841299659083
# F1 Score: 0.7781037210503041
# Weighted F1 Score: 0.7956766371962378
# ==================================================
# Average Accuracy across all folds: 0.7967091073540666
# Average F1 Score across all folds: 0.7754749668276049
# Average Weighted F1 Score across all folds: 0.7953112009342673
# Average Precision across all folds: 0.7965993467758292
# Average Recall across all folds: 0.7967091073540666

# %%
cHL_CODEX.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/results_logreg.

# %%
del cHL2, cHL1, cHL_CODEX

# %%
MRL_CODEX = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None

# %%
MRL_CODEX.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/kfolds')
# Out:
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8109939459885542
# Recall: 0.8163886637470117
# Accuracy: 0.8163886637470117
# F1 Score: 0.6564527746697326
# Weighted F1 Score: 0.8112214763842707
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8116845457406126
# Recall: 0.817191118376243
# Accuracy: 0.817191118376243
# F1 Score: 0.6538384417042311
# Weighted F1 Score: 0.8119955108913369
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.8119275294581002
# Recall: 0.8176134041683695
# Accuracy: 0.8176134041683695
# F1 Score: 0.6597349945567036
# Weighted F1 Score: 0.8123496123147684
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.8113288480022091
# Recall: 0.8167483994006266
# Accuracy: 0.8167483994006266
# F1 Score: 0.658918770340418
# Weighted F1 Score: 0.8113213704415192
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.8118220156014222
# Recall: 0.8174295055169596
# Accuracy: 0.8174295055169596
# F1 Score: 0.6642301118885889
# Weighted F1 Score: 0.8122698369295545
# ==================================================
# Average Accuracy across all folds: 0.817074218241842
# Average F1 Score across all folds: 0.6586350186319349
# Average Weighted F1 Score across all folds: 0.81183156139229
# Average Precision across all folds: 0.8115513769581796
# Average Recall across all folds: 0.817074218241842

# %%
MRL_CODEX.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/results_logreg.

# %%
TB = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
TB.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8017094419605804
# Recall: 0.8021124968185289
# Accuracy: 0.8021124968185289
# F1 Score: 0.8104642842936884
# Weighted F1 Score: 0.8017445086889976
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.7955311341523765
# Recall: 0.7959781086928853
# Accuracy: 0.7959781086928853
# F1 Score: 0.8114824101497875
# Weighted F1 Score: 0.795165351359796
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.7915579903425582
# Recall: 0.7921598574519537
# Accuracy: 0.7921598574519537
# F1 Score: 0.7935629630130987
# Weighted F1 Score: 0.791305584956197
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.8060059248318757
# Recall: 0.806032836960672
# Accuracy: 0.806032836960672
# F1 Score: 0.815592253991905
# Weighted F1 Score: 0.8055737316960697
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.8026172713360106
# Recall: 0.8034873361333842
# Accuracy: 0.8034873361333842
# F1 Score: 0.8144404914517513
# Weighted F1 Score: 0.8022127465492938
# ==================================================
# Average Accuracy across all folds: 0.7999541272114848
# Average F1 Score across all folds: 0.8091084805800461
# Average Weighted F1 Score across all folds: 0.7992003846500709
# Average Precision across all folds: 0.7994843525246803
# Average Recall across all folds: 0.7999541272114848

# %%
TB.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/results_logreg.

# %%
sarc = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
sarc.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.7932169551388523
# Recall: 0.794344473007712
# Accuracy: 0.794344473007712
# F1 Score: 0.804196225758238
# Weighted F1 Score: 0.7932381355169554
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8037493992871196
# Recall: 0.8040953816151051
# Accuracy: 0.8040953816151051
# F1 Score: 0.8101649598974093
# Weighted F1 Score: 0.8035320059553203
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.8053804937096879
# Recall: 0.8059397163120567
# Accuracy: 0.8059397163120567
# F1 Score: 0.8089654549677368
# Weighted F1 Score: 0.8051566918366221
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.7998626880580364
# Recall: 0.8000886524822695
# Accuracy: 0.8000886524822695
# F1 Score: 0.8083968066769052
# Weighted F1 Score: 0.7994795509356485
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.8015526147171702
# Recall: 0.8022163120567376
# Accuracy: 0.8022163120567376
# F1 Score: 0.8032765222313027
# Weighted F1 Score: 0.8010916847870362
# ==================================================
# Average Accuracy across all folds: 0.8013369070947762
# Average F1 Score across all folds: 0.8069999939063184
# Average Weighted F1 Score across all folds: 0.8004996138063165
# Average Precision across all folds: 0.8007524301821732
# Average Recall across all folds: 0.8013369070947762

# %%
sarc.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/results_logreg.

# %%
del MRL_CODEX, TB, sarc

# %%
tonsil_codex = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
tonsil_codex.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8657016371797623
# Recall: 0.8651539202165032
# Accuracy: 0.8651539202165032
# F1 Score: 0.784576121196793
# Weighted F1 Score: 0.8644037682354696
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8664032009891075
# Recall: 0.8658009784532112
# Accuracy: 0.8658009784532112
# F1 Score: 0.7870326308415767
# Weighted F1 Score: 0.8651058489129023
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.8659704315106219
# Recall: 0.8649422296242323
# Accuracy: 0.8649422296242323
# F1 Score: 0.7930190713128915
# Weighted F1 Score: 0.8641659127098218
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.86739930662812
# Recall: 0.8667117726657646
# Accuracy: 0.8667117726657646
# F1 Score: 0.7937966006953012
# Weighted F1 Score: 0.8660860431689482
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.8664431226006712
# Recall: 0.8658009784532112
# Accuracy: 0.8658009784532112
# F1 Score: 0.8009795186269026
# Weighted F1 Score: 0.8652162045960997
# ==================================================
# Average Accuracy across all folds: 0.8656819758825846
# Average F1 Score across all folds: 0.791880788534693
# Average Weighted F1 Score across all folds: 0.8649955555246484
# Average Precision across all folds: 0.8663835397816566
# Average Recall across all folds: 0.8656819758825846

# %%
tonsil_codex.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/results_logreg.

# %%
tonsil_CODEX2 = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
tonsil_CODEX2.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.7749227422180128
# Recall: 0.7884144601474851
# Accuracy: 0.7884144601474851
# F1 Score: 0.6235584540032841
# Weighted F1 Score: 0.7765632699747999
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.7751665544242755
# Recall: 0.7887255648696256
# Accuracy: 0.7887255648696256
# F1 Score: 0.623938473632703
# Weighted F1 Score: 0.776913943558209
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.7745160543850562
# Recall: 0.7883629669520963
# Accuracy: 0.7883629669520963
# F1 Score: 0.6237737669591162
# Weighted F1 Score: 0.7764313715088461
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.7749568783874149
# Recall: 0.7879612941984209
# Accuracy: 0.7879612941984209
# F1 Score: 0.6220645747428794
# Weighted F1 Score: 0.7763288456129729
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.7760619545894658
# Recall: 0.7893129934775146
# Accuracy: 0.7893129934775146
# F1 Score: 0.6246702501599407
# Weighted F1 Score: 0.7776062340346561
# ==================================================
# Average Accuracy across all folds: 0.7885554559290285
# Average F1 Score across all folds: 0.6236011038995847
# Average Weighted F1 Score across all folds: 0.7767687329378968
# Average Precision across all folds: 0.7751248368008451
# Average Recall across all folds: 0.7885554559290285

# %%
tonsil_CODEX2.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/results_logreg.

# %%
del tonsil_codex, tonsil_CODEX2

# %%
lymphoma_CODEX = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
lymphoma_CODEX.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8036831965862901
# Recall: 0.8166647189024803
# Accuracy: 0.8166647189024803
# F1 Score: 0.6551175657450143
# Weighted F1 Score: 0.8054421727944727
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8033749428649914
# Recall: 0.8165961810348691
# Accuracy: 0.8165961810348691
# F1 Score: 0.6518941177081884
# Weighted F1 Score: 0.8053110916173866
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.8034548051434482
# Recall: 0.8165232497142059
# Accuracy: 0.8165232497142059
# F1 Score: 0.6532786821751286
# Weighted F1 Score: 0.8052436006904952
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.8035821564339891
# Recall: 0.8167789486818323
# Accuracy: 0.8167789486818323
# F1 Score: 0.6530420626702158
# Weighted F1 Score: 0.8055106625555765
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.8036959378729313
# Recall: 0.8169773719395179
# Accuracy: 0.8169773719395179
# F1 Score: 0.6535626006245271
# Weighted F1 Score: 0.8056480746267211
# ==================================================
# Average Accuracy across all folds: 0.8167080940545812
# Average F1 Score across all folds: 0.6533790057846148
# Average Weighted F1 Score across all folds: 0.8054311204569304
# Average Precision across all folds: 0.8035582077803302
# Average Recall across all folds: 0.8167080940545812

# %%
lymphoma_CODEX.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/results_logreg.

# %%
intestine_CODEX = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
intestine_CODEX.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8819555813926662
# Recall: 0.8828950300013061
# Accuracy: 0.8828950300013061
# F1 Score: 0.7915284725902819
# Weighted F1 Score: 0.880531620529539
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8816275809944654
# Recall: 0.8828431711495763
# Accuracy: 0.8828431711495763
# F1 Score: 0.7917494787328957
# Weighted F1 Score: 0.8804165003688491
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.8823316321706274
# Recall: 0.8832309279102956
# Accuracy: 0.8832309279102956
# F1 Score: 0.7936767070557338
# Weighted F1 Score: 0.8808344941081941
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.8826802071879183
# Recall: 0.8837303104046342
# Accuracy: 0.8837303104046342
# F1 Score: 0.7926014964724588
# Weighted F1 Score: 0.8813100439581613
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.8826591164233806
# Recall: 0.8835728128487275
# Accuracy: 0.8835728128487275
# F1 Score: 0.7984281956295236
# Weighted F1 Score: 0.8812539026955741
# ==================================================
# Average Accuracy across all folds: 0.8832544504629081
# Average F1 Score across all folds: 0.7935968700961787
# Average Weighted F1 Score across all folds: 0.8808693123320636
# Average Precision across all folds: 0.8822508236338115
# Average Recall across all folds: 0.8832544504629081

# %%
intestine_CODEX.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/results_logreg.

# %%
del lymphoma_CODEX, intestine_CODEX

# %%
feto_maternal = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
feto_maternal.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8624251123650618
# Recall: 0.8645503179570001
# Accuracy: 0.8645503179570001
# F1 Score: 0.7972494423292438
# Weighted F1 Score: 0.8631157119390919
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8616181582809187
# Recall: 0.863752901988493
# Accuracy: 0.863752901988493
# F1 Score: 0.7826586633186642
# Weighted F1 Score: 0.8622955121753026
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.8590628425474428
# Recall: 0.8612092459876854
# Accuracy: 0.8612092459876854
# F1 Score: 0.7897574596621685
# Weighted F1 Score: 0.8598213027792284
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.8618325786278895
# Recall: 0.8639749671949127
# Accuracy: 0.8639749671949127
# F1 Score: 0.796161262537387
# Weighted F1 Score: 0.8625371060132614
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.861730643394544
# Recall: 0.8639332182620194
# Accuracy: 0.8639332182620194
# F1 Score: 0.790316926447078
# Weighted F1 Score: 0.862471896426664
# ==================================================
# Average Accuracy across all folds: 0.8634841302780221
# Average F1 Score across all folds: 0.7912287508589083
# Average Weighted F1 Score across all folds: 0.8620483058667097
# Average Precision across all folds: 0.8613338670431713
# Average Recall across all folds: 0.8634841302780221

# %%
feto_maternal.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/results_logreg.

# %%
CRC_FFPE = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
CRC_FFPE.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.7913509824489326
# Recall: 0.7966019699285949
# Accuracy: 0.7966019699285949
# F1 Score: 0.6684098136620555
# Weighted F1 Score: 0.7893888378025431
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.790637962032278
# Recall: 0.7949184356677051
# Accuracy: 0.7949184356677051
# F1 Score: 0.6694233596133724
# Weighted F1 Score: 0.7885122798293023
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.7906885180463695
# Recall: 0.7954215608491205
# Accuracy: 0.7954215608491205
# F1 Score: 0.6639072456246956
# Weighted F1 Score: 0.7885547747551864
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.7921038452428084
# Recall: 0.7962149505582754
# Accuracy: 0.7962149505582754
# F1 Score: 0.6782555609394053
# Weighted F1 Score: 0.7899688525099492
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.788570431816139
# Recall: 0.793544516903071
# Accuracy: 0.793544516903071
# F1 Score: 0.6717600853456965
# Weighted F1 Score: 0.7872115603476151
# ==================================================
# Average Accuracy across all folds: 0.7953402867813535
# Average F1 Score across all folds: 0.6703512130370451
# Average Weighted F1 Score across all folds: 0.7887272610489193
# Average Precision across all folds: 0.7906703479173054
# Average Recall across all folds: 0.7953402867813535

# %%
CRC_FFPE.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/results_logreg.

# %%
BE_tonsil = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
BE_tonsil.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8962184367810062
# Recall: 0.8972854999317965
# Accuracy: 0.8972854999317965
# F1 Score: 0.886766169378179
# Weighted F1 Score: 0.8963176158041181
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8982000282243401
# Recall: 0.8988973513697851
# Accuracy: 0.8988973513697851
# F1 Score: 0.8859086333278644
# Weighted F1 Score: 0.8981384900527639
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.901749616600555
# Recall: 0.9024667500284188
# Accuracy: 0.9024667500284188
# F1 Score: 0.8978004440273619
# Weighted F1 Score: 0.9017078108373394
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.8994347999655496
# Recall: 0.9001250426281687
# Accuracy: 0.9001250426281687
# F1 Score: 0.8926165533545566
# Weighted F1 Score: 0.8994115962341037
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.9000204754384801
# Recall: 0.900829828350574
# Accuracy: 0.900829828350574
# F1 Score: 0.8924893246362134
# Weighted F1 Score: 0.9000191806551013
# ==================================================
# Average Accuracy across all folds: 0.8999208944617486
# Average F1 Score across all folds: 0.8911162249448351
# Average Weighted F1 Score across all folds: 0.8991189387166851
# Average Precision across all folds: 0.8991246714019863
# Average Recall across all folds: 0.8999208944617486

# %%
BE_tonsil.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/results_logreg.

# %%
tonsil_training = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
tonsil_training.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8718495933832763
# Recall: 0.8710755784682925
# Accuracy: 0.8710755784682925
# F1 Score: 0.8385564848136768
# Weighted F1 Score: 0.8696993087268597
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8738711316439408
# Recall: 0.8732706365668486
# Accuracy: 0.8732706365668486
# F1 Score: 0.8363469766068737
# Weighted F1 Score: 0.8719328935296741
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.8736890487114157
# Recall: 0.8733511891576213
# Accuracy: 0.8733511891576213
# F1 Score: 0.8462818466907952
# Weighted F1 Score: 0.8719048649339901
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.8728015963237923
# Recall: 0.8724449725114284
# Accuracy: 0.8724449725114284
# F1 Score: 0.8356423762373163
# Weighted F1 Score: 0.8711846857397546
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.8744270452878056
# Recall: 0.8737338139637916
# Accuracy: 0.8737338139637916
# F1 Score: 0.8384338357204429
# Weighted F1 Score: 0.872463193526653
# ==================================================
# Average Accuracy across all folds: 0.8727752381335965
# Average F1 Score across all folds: 0.8390523040138211
# Average Weighted F1 Score across all folds: 0.8714369892913864
# Average Precision across all folds: 0.8733276830700462
# Average Recall across all folds: 0.8727752381335965

# %%
tonsil_training.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/results_logreg.

# %%
del feto_maternal, CRC_FFPE, BE_tonsil, tonsil_training

# %%
AML = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
AML.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 1 results:
# Precision: 0.7837549305195335
# Recall: 0.7868144281113095
# Accuracy: 0.7868144281113095
# F1 Score: 0.6188529457591873
# Weighted F1 Score: 0.7838042343458248
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 2 results:
# Precision: 0.7814781486993546
# Recall: 0.7842957671230786
# Accuracy: 0.7842957671230786
# F1 Score: 0.6242070523838886
# Weighted F1 Score: 0.7816473374202871
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 3 results:
# Precision: 0.7853469110944908
# Recall: 0.7880355970753004
# Accuracy: 0.7880355970753004
# F1 Score: 0.6301477557134355
# Weighted F1 Score: 0.7855500613782602
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Fold 4 results:
# Precision: 0.7846783815538574
# Recall: 0.7880050678512006
# Accuracy: 0.7880050678512006
# F1 Score: 0.622933393648149
# Weighted F1 Score: 0.7850251124218254
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.7863410831798444
# Recall: 0.7893025598754407
# Accuracy: 0.7893025598754407
# F1 Score: 0.6301732726376272
# Weighted F1 Score: 0.7864774468390354
# ==================================================
# Average Accuracy across all folds: 0.7872906840072661
# Average F1 Score across all folds: 0.6252628840284575
# Average Weighted F1 Score across all folds: 0.7845008384810466
# Average Precision across all folds: 0.7843198910094161
# Average Recall across all folds: 0.7872906840072661
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
AML.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/results_logreg.

# %%
healthy_BM = MultinomialLogisticRegression(random_state = rs, n_jobs=-1)
healthy_BM.train_and_evaluate_manual(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/kfolds')
# Out:
# MultinomialLogisticRegression class initialized successfully with the following parameters:
#   Random State: 20240925
#   Max Iterations: 1000
#   C (Inverse of Regularization Strength): 1.0
#   Penalty: l2
#   L1 Ratio: None
#   Solver: lbfgs
#   Number of Jobs: -1
#   Class Weight: None
# Data in fold_1_train.csv and fold_1_test.csv is clean.
# Data in fold_2_train.csv and fold_2_test.csv is clean.
# Data in fold_3_train.csv and fold_3_test.csv is clean.
# Data in fold_4_train.csv and fold_4_test.csv is clean.
# Data in fold_5_train.csv and fold_5_test.csv is clean.
# Taking data from fold_1_train.csv and fold_1_test.csv for fold 1.
# Training fold 1...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 1 results:
# Precision: 0.8554852918271673
# Recall: 0.8573982685203463
# Accuracy: 0.8573982685203463
# F1 Score: 0.7283016670096187
# Weighted F1 Score: 0.8558273392411023
# ==================================================
# Taking data from fold_2_train.csv and fold_2_test.csv for fold 2.
# Training fold 2...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 2 results:
# Precision: 0.8554366331445129
# Recall: 0.8573249485350103
# Accuracy: 0.8573249485350103
# F1 Score: 0.7297739023881336
# Weighted F1 Score: 0.8558963430344386
# ==================================================
# Taking data from fold_3_train.csv and fold_3_test.csv for fold 3.
# Training fold 3...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 3 results:
# Precision: 0.8556975574071486
# Recall: 0.8576238684752263
# Accuracy: 0.8576238684752263
# F1 Score: 0.7340927691861989
# Weighted F1 Score: 0.8561490702380847
# ==================================================
# Taking data from fold_4_train.csv and fold_4_test.csv for fold 4.
# Training fold 4...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 4 results:
# Precision: 0.8527064237654309
# Recall: 0.8548997490200502
# Accuracy: 0.8548997490200502
# F1 Score: 0.7279855579653396
# Weighted F1 Score: 0.8532215046846844
# ==================================================
# Taking data from fold_5_train.csv and fold_5_test.csv for fold 5.
# Training fold 5...
# /Users/lukashat/miniforge3/envs/cML_benchmark/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Fold 5 results:
# Precision: 0.8553851780149334
# Recall: 0.8572967485406503
# Accuracy: 0.8572967485406503
# F1 Score: 0.7252568490041349
# Weighted F1 Score: 0.8557873053972341
# ==================================================
# Average Accuracy across all folds: 0.8569087166182566
# Average F1 Score across all folds: 0.7290821491106851
# Average Weighted F1 Score across all folds: 0.855376312519109
# Average Precision across all folds: 0.8549422168318387
# Average Recall across all folds: 0.8569087166182566

# %%
healthy_BM.save_results(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/results_logreg', label_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/labels.csv')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/results_logreg exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving model...
# Results and model saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/results_logreg.
