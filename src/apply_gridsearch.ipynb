# %%
import pandas as pd
import numpy as np
from models_classes.gridsearch import Tune_Eval

# %% [markdown]
# # Test suite for gridsearch script

# %%
rs = 42
param_grid = {
    'n_estimators': [100],
    'max_depth': [5],
    'learning_rate' : [0.1],
}

# %%
cHL2 = Tune_Eval(rs, model='xgboost', min_child_weight=2)
# Out:
# GirdSearcher class initialized successfully with the following model parameters:
# Random State: 42
# Model: XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=2, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=1, num_parallel_tree=None, objective='multi:softmax', ...)

# %%
cHL2.train_tune_evaluate(
    path = '/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/kfolds',
    param_grid = param_grid,
    n_jobs=6,
    sample_weight='balanced'
)
# Out:
# Starting the integration of the predefined Kfolds...
# Taking data from fold_1_train.csv and fold_1_validation.csv for fold 1. No NANs found
# Fold 1 integrated successfully
# Taking data from fold_2_train.csv and fold_2_validation.csv for fold 2. No NANs found
# Fold 2 integrated successfully
# Taking data from fold_3_train.csv and fold_3_validation.csv for fold 3. No NANs found
# Fold 3 integrated successfully
# Taking data from fold_4_train.csv and fold_4_validation.csv for fold 4. No NANs found
# Fold 4 integrated successfully
# Taking data from fold_5_train.csv and fold_5_validation.csv for fold 5. No NANs found
# Fold 5 integrated successfully
# PredefinedSplit created successfully
# Starting GridSearchCV with the following grid parameters:
# {'n_estimators': [100], 'max_depth': [5], 'learning_rate': [0.1]}
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time= 1.6min
# ...

# %%
cHL2.save_results('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/results_xgboost', '/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/labels.csv', '/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/kfolds')
# Out:
# The path /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/results_xgboost exists. Saving results in the specified directory.
# Saving average results...
# Saving confusion matrices...
# Saving classification reports...
# Saving predictions on test csv...
# Saving model in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/results_xgboost/model...
# Best models for all folds saved successfully in /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/results_xgboost/model.
