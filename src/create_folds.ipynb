# %%
import os
import json
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold, KFold
from sklearn.preprocessing import LabelEncoder
from data_handler import DataSetHandler

# %%
rs = 20240925

# %%
cHL1 = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/cHL1_MIBI_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
cHL1.preprocess(dropna=False)
# Out:
# Data successfully preprocessed

# %%
cHL1.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/')
cHL1.createKfold(k=5)
cHL1.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/kfolds

# %%
cHL2 = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/cHL2_MIBI_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
cHL2.preprocess(dropna=False)
# Out:
# Data successfully preprocessed

# %%
cHL2.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/')
cHL2.createKfold(k=5)
cHL2.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/kfolds

# %%
cHL_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/cHL_CODEX_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
cHL_CODEX.preprocess(dropna=False)
# Out:
# Data successfully preprocessed

# %%
cHL_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/')
cHL_CODEX.createKfold(k=5)
cHL_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/kfolds

# %%
sarc = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/allTB-sarcoid-scdata_reshaped_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
sarc.preprocess(dropna=False, drop_columns = ["C", "Na"], impute_value = 0) #group_identifier_column = 'PatientROI')
# Out:
# Data successfully preprocessed

# %%
sarc.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc')
sarc.createKfold(k=5)
sarc.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/kfolds

# %%
tb = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/allTB-ME_annotated_reshaped_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
tb.preprocess(dropna=False, drop_columns = ["C", "Na"], impute_value = 0)# group_identifier_column = 'PatientROI')
# Out:
# Data successfully preprocessed

# %%
tb.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB')
tb.createKfold(k=5)
tb.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/kfolds

# %%
del cHL1, cHL2, cHL_CODEX, sarc, tb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 del cHL1, cHL2, cHL_CODEX, sarc, tb
#
# NameError: name 'cHL1' is not defined

# %%
tonsil_codex = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/Tonsil_Clustering16_K46_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
tonsil_codex.data.isna().sum()
# Out:
# CD56           0
# FoxP3          0
# CD21           0
# MUC1           0
# PD1            0
# CD11b          0
# CD4            0
# Ki67           0
# CD31           0
# CD25           0
# CD15           0
# CD20           0
# Annexin A1     0
# aSMA           0
# CD11c          0
# Nestin         0
# IDO            0
# Cytokeratin    0
# Vimentin       0
# CD36           0
# HLADR          0
# BCL2           0
# p63            0
# CD3            0
# CD45           0
# CD8            0
# CD57           0
# CD68           0
# CD34           0
# CD38           0
# Podoplanin     0
# CD163          0
# Bcatenin       0
# CD138          0
# Arginase1      0
# CD73           0
# CD206          0
# COX2           0
# MMP9           0
# PDL1           0
# p53            0
# cell_type      0
# dtype: int64

# %%
tonsil_codex.preprocess(dropna=False)
# Out:
# Data successfully preprocessed

# %%
tonsil_codex.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/')
tonsil_codex.createKfold(k=5)
tonsil_codex.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/kfolds

# %%
del tonsil_codex

# %%
tonsil_CODEX2 = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/Lymphoid_Data_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
tonsil_CODEX2.data.isna().sum()
# Out:
# CD38           0
# CD19           0
# CD31           0
# Vimentin       0
# CD22           0
# Ki67           0
# CD8            0
# Cd90           0
# CD123          0
# CD15           0
# CD3            0
# CD152          0
# CD21           0
# Cytokeratin    0
# CD2            0
# CD66           0
# CollagenIV     0
# Cd81           0
# HLADR          0
# CD57           0
# CD4            0
# CD7            0
# CD278          0
# podoplanin     0
# CD45RA         0
# CD34           0
# CD54           0
# CD9            0
# IgM            0
# CD117          0
# CD56           0
# CD279          0
# CD45           0
# CD49f          0
# CD5            0
# CD16           0
# CD63           0
# CD11b          0
# CD1c           0
# CD40           0
# CD27           0
# CD104          0
# CD273          0
# HOECHST1       0
# :size.size     0
# file_key       0
# cell_type      0
# dtype: int64

# %%
tonsil_CODEX2.preprocess(dropna=False)#, group_identifier_column = 'file_key')
# Out:
# Data successfully preprocessed

# %%
tonsil_CODEX2.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/')
tonsil_CODEX2.createKfold(k=5)
tonsil_CODEX2.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/kfolds

# %%
lymphoma_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/lymphoma_CODEX_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
lymphoma_CODEX.data.isna().sum()
# Out:
# BCL6             0
# GATA3            0
# CXCR5            0
# Tbet             0
# CD62L            0
# TIM3             0
# CD134            0
# IL10             0
# CTLA4            0
# CXCL13           0
# PD1              0
# LAG3             0
# CD45RO           0
# ICOS             0
# CD69             0
# CD45RA           0
# GRZB             0
# CD44             0
# PAX5             0
# FOXP3            0
# CD45             0
# CD20             0
# CD79a            0
# CD21             0
# CD38             0
# lambda           0
# kappa            0
# CD3              0
# CD7              0
# CD5              0
# CD4              0
# CD8              0
# CD56             0
# CD57             0
# CD25             0
# CD11b            0
# CD15             0
# CD14             0
# CD16             0
# CD68             0
# CD163            0
# CD206            0
# CD11c            0
# MCT              0
# CD34             0
# CD31             0
# CD90             0
# PDPN             0
# HLA-DR           0
# Ki67             0
# Hoechst1         0
# DRAQ5            0
# unique_region    0
# cell_type        0
# dtype: int64

# %%
lymphoma_CODEX.preprocess(dropna=False)#, group_identifier_column = 'unique_region')
# Out:
# Data successfully preprocessed

# %%
lymphoma_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/')
lymphoma_CODEX.createKfold(k=5)
lymphoma_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/kfolds

# %%
del lymphoma_CODEX, tonsil_CODEX2

# %%
intestine_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/23_09_CODEX_HuBMAP_alldata_Dryad_merged_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
intestine_CODEX.data.isna().sum()
# Out:
# MUC2                   0
# SOX9                   0
# MUC1                   0
# CD31                   0
# Synapto                0
# CD49f                  0
# CD15                   0
# CHGA                   0
# CDX2                   0
# ITLN1                  0
# CD4                    0
# CD127                  0
# Vimentin               0
# HLADR                  0
# CD8                    0
# CD11c                  0
# CD44                   0
# CD16                   0
# BCL2                   0
# CD3                    0
# CD123                  0
# CD38                   0
# CD90                   0
# aSMA                   0
# CD21                   0
# NKG2D                  0
# CD66                   0
# CD57                   0
# CD206                  0
# CD68                   0
# CD34                   0
# aDef5                  0
# CD7                    0
# CD36                   0
# CD138                  0
# CD45RO                 0
# Cytokeratin            0
# CD117                  0
# CD19                   0
# Podoplanin             0
# CD45                   0
# CD56                   0
# CD69                   0
# Ki67                   0
# CD49a                  0
# CD163                  0
# CD161                  0
# OLFM4             248287
# FAP               248287
# CD25              248287
# CollIV            248287
# CK7              1735893
# MUC6             1214949
# unique_region          0
# cell_type              0
# dtype: int64

# %%
intestine_CODEX.preprocess(dropna=False, impute_value = 0)
# Out:
# Data successfully preprocessed

# %%
intestine_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/')
intestine_CODEX.createKfold(k=5)
intestine_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/kfolds

# %%
del intestine_CODEX

# %%
feto_maternal = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/decidua_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
feto_maternal.data.isna().sum()
# Out:
# CD11c                   0
# CD14                    0
# CD16                    0
# CD163                   0
# CD20                    0
# CD206                   0
# CD3                     0
# CD31                    0
# CD4                     0
# CD44                    0
# CD45                    0
# CD56                    0
# CD57                    0
# CD68                    0
# CD8                     0
# CD80                    0
# CK7                     0
# DC-SIGN                 0
# Ecad                    0
# FoxP3                   0
# Galectin-9              0
# GrB                     0
# H3                      0
# HLA-DR                  0
# HLA-G                   0
# HO-1                    0
# IDO-1                   0
# Ki67_raw                0
# Lck                     0
# PD-1                    0
# PD-L1                   0
# SMA                     0
# TIGIT                   0
# TIM-3                   0
# Tryptase                0
# VIM                     0
# background              0
# iNOS                    0
# area                    0
# cell_size               0
# eccentricity            0
# major_axis_length       0
# minor_axis_length       0
# perimeter               0
# Point                   0
# area_nuclear            0
# nucleated               0
# overlap_decidua_only    0
# cell_type               0
# dtype: int64

# %%
feto_maternal.preprocess(dropna=False, drop_columns=['point_mean_delta', 'distance_from_artery'])#, group_identifier_column = 'Point')
# Out:
# Data successfully preprocessed

# %%
feto_maternal.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/')
feto_maternal.createKfold(k=5)
feto_maternal.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/kfolds

# %%
CRC_FFPE = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/CRC_FFPE_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
CRC_FFPE.data.isna().sum().sum()
# Out:
# 0

# %%
CRC_FFPE.preprocess(dropna=False)#, group_identifier_column = 'File Name')
# Out:
# Data successfully preprocessed

# %%
CRC_FFPE.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/')
CRC_FFPE.createKfold(k=5)
CRC_FFPE.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/kfolds

# %%
be_tonsil = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/BE_Tonsil_l3_dryad_cleaned.csv', random_state = rs)
tonsil_training = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/B004_training_dryad_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully
# DataSetHandler initialized successfully

# %%
print(be_tonsil.data.isna().sum().sum())
tonsil_training.data.isna().sum().sum()
# Out:
# 0
# 0

# %%
be_tonsil.preprocess(dropna=False)#, group_identifier_column = 'sample_name')
tonsil_training.preprocess(dropna=False)#, group_identifier_column = 'unique_region')
# Out:
# Data successfully preprocessed
# Data successfully preprocessed

# %%
be_tonsil.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/')
tonsil_training.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/')
be_tonsil.createKfold(k=5)
tonsil_training.createKfold(k=5)
be_tonsil.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/')
tonsil_training.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/ as labels.csv
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/kfolds
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/kfolds

# %%
del be_tonsil, tonsil_training, feto_maternal, CRC_FFPE

# %%
aml = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/AML_cleaned.csv', random_state = rs)
bm = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/normal_bone_marrow_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully
# DataSetHandler initialized successfully

# %%
aml.data.isna().sum().sum()
# Out:
# 0

# %%
bm.data.isna().sum().sum()
# Out:
# 0

# %%
aml.preprocess(dropna=False)#, group_identifier_column = 'orig.ident')
bm.preprocess(dropna=False)#, group_identifier_column = 'orig.ident')
# Out:
# Data successfully preprocessed
# Data successfully preprocessed

# %%
aml.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/')
bm.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/')
aml.createKfold(k=5)
bm.createKfold(k=5)
aml.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/')
bm.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/ as labels.csv
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# No group identifier column specified, KFold will be used
# /Users/lukashat/miniforge3/envs/preprocess_benchmark/lib/python3.10/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/kfolds
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/kfolds

# %%
MRL_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/Suppl.Table2.CODEX_paper_MRLdatasetexpression_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
MRL_CODEX.data.isna().sum().sum()
# Out:
# 0

# %%
MRL_CODEX.preprocess(dropna=False)
# Out:
# Data successfully preprocessed

# %%
MRL_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/')
MRL_CODEX.createKfold(k=5)
MRL_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/kfolds
