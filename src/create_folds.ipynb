# %%
import os
import json
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold, KFold
from sklearn.preprocessing import LabelEncoder
from data_handler import DataSetHandler

# %%
cHL1 = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/cHL1_MIBI_cleaned.csv', random_state = 20240923)
# Out:
# DataSetHandler initialized successfully

# %%
cHL1.preprocess(dropna=False, group_identifier_column = 'identifier')
# Out:
# Data successfully preprocessed

# %%
cHL1.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/')
cHL1.createKfold(k=5)
cHL1.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/ as labels.csv
# Group identifier column specified, GroupKFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/kfolds

# %%
cHL2 = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/cHL2_MIBI_cleaned.csv', random_state = 20240923)
# Out:
# DataSetHandler initialized successfully

# %%
cHL2.preprocess(dropna=False)
# Out:
# Data successfully preprocessed

# %%
cHL2.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/')
cHL2.createKfold(k=5)
cHL2.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/kfolds

# %%
cHL_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/cHL_CODEX_cleaned.csv', random_state = 20240923)
# Out:
# DataSetHandler initialized successfully

# %%
cHL_CODEX.data
# Out:
#            BCL.2      CCR6     CD11b     CD11c      CD15      CD16     CD162  \
# 0       0.792642  0.617038  0.000089  0.000040  0.000029  0.097688  0.007772
# 1       0.000000  0.127394  0.062173  0.660572  0.000000  0.000000  0.172885
# 2       0.060620  0.134818  0.298522  0.083348  0.000000  0.182152  0.000210
# 3       0.000000  0.012896  0.287698  0.268121  0.000000  0.124361  0.016805
# 4       0.201057  0.110590  0.000000  0.000000  0.000000  0.000000  0.745316
# ...          ...       ...       ...       ...       ...       ...       ...
# 143725  0.000000  0.523642  1.000000  0.182044  1.000000  1.000000  0.055458
# 143726  0.000000  0.210238  0.313372  0.076860  0.986128  0.587575  0.044324
# 143727  0.000000  0.620555  0.000089  0.025792  0.000029  0.255168  0.000000
# 143728  0.000000  0.597890  0.000000  0.099606  0.000029  0.370193  0.012604
# 143729  0.000000  0.030481  0.000000  0.083704  0.000058  1.000000  0.000000
#
# ...

# %%
cHL_CODEX.preprocess(dropna=False)
# Out:
# Data successfully preprocessed

# %%
cHL_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/')
cHL_CODEX.createKfold(k=5)
cHL_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/ as labels.csv
# No group identifier column specified, KFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/kfolds

# %%
sarc = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tb_sarc/quantification/processed/sarc/allTB-sarcoid-scdata_reshaped_cleaned.csv', random_state = 20240923)
# Out:
# DataSetHandler initialized successfully

# %%
sarc.data.isna().sum()
# Out:
# C               12960
# Na               9506
# HH3                 0
# Vimentin            0
# SMA                 0
# Collagen.1          0
# Lag3                0
# CD4                 0
# CD14                0
# Foxp3               0
# PD.1                0
# CD31                0
# PD.L1               0
# E.cadherin       9506
# Ki67                0
# CD209            9506
# CD206               0
# gdTCR            9506
# iNOS                0
# CD68                0
# CD36             9506
# CD8                 0
# CD3                 0
# IDO                 0
# CD11c               0
# CD163               0
# CD20                0
# CD16             9506
# IFNg                0
# HLA.DR.DQ.DP        0
# CD11b               0
# CD45                0
# H3K9Ac              0
# Keratin.pan      9506
# CD103            9506
# MastChyTry          0
# MPO                 0
# NaKATPase        9506
# HLA.Class.1      9506
# Ta                  0
# Au                  0
# ...

# %%
sarc.data
# Out:
#               C        Na       HH3  Vimentin  SMA  Collagen.1  Lag3  \
# 0      0.911187  0.813581  0.765556  0.786841  0.0    0.000000   0.0
# 1      0.912404  0.857459  0.881312  0.726815  0.0    0.018747   0.0
# 2      0.890122  0.838072  0.839182  0.795838  0.0    0.000000   0.0
# 3      0.900242  0.861314  0.797691  0.509005  0.0    0.000000   0.0
# 4      0.891710  0.880452  0.910139  0.544552  0.0    0.000000   0.0
# ...         ...       ...       ...       ...  ...         ...   ...
# 56397       NaN       NaN  0.579460  0.000000  0.0    0.000000   0.0
# 56398       NaN       NaN  0.637259  0.000000  0.0    0.000000   0.0
# 56399       NaN       NaN  0.667161  0.000000  0.0    0.000000   0.0
# 56400       NaN       NaN  0.617340  0.000000  0.0    0.000000   0.0
# 56401       NaN       NaN  0.622822  0.000000  0.0    0.000000   0.0
#
#             CD4      CD14  Foxp3  ...  CD103  MastChyTry  MPO  NaKATPase  \
# ...

# %%
sarc.preprocess(dropna=False, group_identifier_column = 'PatientROI')
# Out:
# Data successfully preprocessed

# %%
sarc.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tb_sarc/quantification/processed/')
sarc.createKfold(k=5)
sarc.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tb_sarc/quantification/processed/')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tb_sarc/quantification/processed/ as labels.csv
# Group identifier column specified, GroupKFold will be used
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tb_sarc/quantification/processed/kfolds
