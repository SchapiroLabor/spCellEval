# %%
import os
import json
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold, KFold
from sklearn.preprocessing import LabelEncoder
from models_classes.data_handler import DataSetHandler

# %%
rs = 20240925

# %%
cHL1 = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/cHL1_MIBI_cleaned.csv', random_state = rs)

# %%
cHL1.data['identifier'].value_counts().sum()

# %%
cHL1.preprocess(dropna=False, group_identifier_columns='identifier')

# %%
cHL1.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/')
cHL1.createKfold(k=5)
cHL1.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/')
cHL1.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_1_MIBI/quantification/processed/kfolds')

# %%
cHL2 = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/cHL2_MIBI_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
cHL2.preprocess(dropna=False, group_identifier_columns='csv')
# Out:
# Data successfully preprocessed

# %%
cHL2.group_identifier_columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cHL2.group_identifier_columns
#
# AttributeError: 'DataSetHandler' object has no attribute 'group_identifier_columns'

# %%
cHL2.fold_indices

# %%
cHL2.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/')
cHL2.createKfold(k=5)
cHL2.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed')
cHL2.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_2_MIBI/quantification/processed/kfolds')

# %%
cHL_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/cHL_CODEX_cleaned.csv', random_state = rs)

# %%
cHL_CODEX.data

# %%
cHL_CODEX.preprocess(dropna=False)

# %%
cHL_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/')
cHL_CODEX.createKfold(k=5)
cHL_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/')
cHL_CODEX.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/Maps_data/cHL_CODEX/quantification/processed/kfolds')

# %%
sarc = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/allTB-sarcoid-scdata_reshaped.csv', random_state = rs)

# %%
sarc.preprocess(dropna=False, drop_columns = ["C", "Na"], impute_value = 0, drop_non_numerical=True, group_identifier_colums='PatientROI')

# %%
sarc.X

# %%
sarc.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc')
sarc.createKfold(k=5)
sarc.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc')
sarc.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/sarc/kfolds')

# %%
tb = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/allTB-ME_annotated_reshaped.csv', random_state = rs)

# %%
tb.preprocess(dropna=False, drop_columns = ["C", "Na"], impute_value = 0,drop_non_numerical=True, group_identifier_columns = 'PatientROI')

# %%
tb.X

# %%
tb.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB')
tb.createKfold(k=5)
tb.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/')
tb.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/TB_MIBI_atlas/quantification/processed/TB/kfolds')

# %%
del cHL1, cHL2, cHL_CODEX, sarc, tb

# %%
tonsil_codex = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/Tonsil_Clustering16_K46_cleaned.csv', random_state = rs)

# %%
tonsil_codex.data

# %%
tonsil_codex.data.isna().sum()

# %%
tonsil_codex.preprocess(dropna=False)

# %%
tonsil_codex.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/')
tonsil_codex.createKfold(k=5)
tonsil_codex.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/')
tonsil_codex.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX/quantification/processed/kfolds')

# %%
del tonsil_codex

# %%
tonsil_CODEX2 = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/Lymphoid_Data_cleaned.csv', random_state = rs)

# %%
tonsil_CODEX2.data

# %%
tonsil_CODEX2.preprocess(dropna=False, group_identifier_columns = 'file_key')

# %%
tonsil_CODEX2.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/')
tonsil_CODEX2.createKfold(k=5)
tonsil_CODEX2.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/')
tonsil_CODEX2.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/tonsil_CODEX2/quantification/processed/kfolds')

# %%
lymphoma_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/lymphoma_CODEX_cleaned.csv', random_state = rs)

# %%
lymphoma_CODEX.data

# %%
lymphoma_CODEX.preprocess(dropna=False, group_identifier_columns = 'unique_region')

# %%
lymphoma_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/')
lymphoma_CODEX.createKfold(k=5)
lymphoma_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/')
lymphoma_CODEX.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/lymphoma_CODEX/quantification/processed/kfolds')

# %%
del lymphoma_CODEX, tonsil_CODEX2

# %%
intestine_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/23_09_CODEX_HuBMAP_alldata_Dryad_merged_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
intestine_CODEX.data
# Out:
#              MUC2      SOX9      MUC1      CD31   Synapto     CD49f      CD15  \
# 0       -0.303994 -0.163727 -0.587608 -0.212903  0.164173 -0.664863  0.049305
# 1       -0.301927 -0.491706 -0.500804 -0.243205 -0.142568 -0.664861 -0.182627
# 2       -0.302206 -0.547234 -0.510705 -0.235309 -0.217185 -0.622758 -0.296486
# 3       -0.304219 -0.613068 -0.584499 -0.243757 -0.266696 -0.658449 -0.299027
# 4       -0.294644 -0.615593 -0.570580 -0.247548 -0.042246 -0.642230 -0.299031
# ...           ...       ...       ...       ...       ...       ...       ...
# 2603212  0.351916  0.693827 -0.081489 -0.240643  0.008875  0.143445  0.373710
# 2603213  0.233642  0.171892  0.141842 -0.236145 -0.097772 -0.099283  0.626185
# 2603214 -0.212237 -0.280904 -0.197833 -0.245638 -0.152563 -0.125035  0.430416
# 2603215 -0.328666  0.607609 -0.180362 -0.247351 -0.143742 -0.169576  1.095596
# 2603216  0.015179  1.656635 -0.250193 -0.243560 -0.084982  0.061781  1.300252
#
#              CHGA      CDX2     ITLN1  ...    CollIV       CK7  MUC6    Xcorr  \
# 0        0.003616 -0.377532 -0.450794  ...       NaN -0.168582   NaN  13392.0
# 1       -0.117573 -0.182754 -0.236199  ...       NaN -0.150520   NaN  14596.0
# 2       -0.091504 -0.268055 -0.355383  ...       NaN -0.156116   NaN  15478.0
# 3       -0.121460 -0.345381 -0.450792  ...       NaN -0.136229   NaN  16995.0
# 4       -0.121458 -0.377533 -0.450797  ...       NaN -0.159834   NaN  16200.0
# ...           ...       ...       ...  ...       ...       ...   ...      ...
# 2603212 -0.097896  0.869830  0.579653  ... -0.582639       NaN   NaN  11101.0
# 2603213 -0.105545  0.092076  0.682969  ... -0.607179       NaN   NaN  11093.0
# 2603214 -0.105787 -0.038327 -0.173319  ... -0.697211       NaN   NaN  11172.0
# 2603215 -0.113879  0.370160 -0.133272  ... -0.715124       NaN   NaN   9825.0
# 2603216 -0.108526  1.245830 -0.063456  ... -0.612764       NaN   NaN  10059.0
#
#           Ycorr    array       x       y   unique_region         cell_type
# 0        3387.0  B004_CL  3984.0  3387.0  B004_Ascending                NK
# 1        4116.0  B004_CL  5188.0  4116.0  B004_Ascending                NK
# 2        3146.0  B004_CL  6070.0  3146.0  B004_Ascending                NK
# 3        2361.0  B004_CL  7587.0  2361.0  B004_Ascending                NK
# 4        3891.0  B004_CL  6792.0  3891.0  B004_Ascending                NK
# ...         ...      ...     ...     ...             ...               ...
# 2603212  2079.0    colon  1693.0  2079.0      B008_Trans  CD66+ Enterocyte
# 2603213  2127.0    colon  1685.0  2127.0      B008_Trans  CD66+ Enterocyte
# 2603214  2608.0    colon  1764.0  2608.0      B008_Trans  CD66+ Enterocyte
# 2603215  5095.0    colon   417.0  5095.0      B008_Trans  CD66+ Enterocyte
# 2603216  5855.0    colon   651.0  5855.0      B008_Trans  CD66+ Enterocyte
#
# [2603217 rows x 60 columns]

# %%
intestine_CODEX.preprocess(dropna=False, impute_value = 0, group_identifier_columns=['unique_regions', 'array'])
# Out:
# Data successfully preprocessed

# %%
intestine_CODEX.X
# Out:
#              MUC2      SOX9      MUC1      CD31   Synapto     CD49f      CD15  \
# 0       -0.303994 -0.163727 -0.587608 -0.212903  0.164173 -0.664863  0.049305
# 1       -0.301927 -0.491706 -0.500804 -0.243205 -0.142568 -0.664861 -0.182627
# 2       -0.302206 -0.547234 -0.510705 -0.235309 -0.217185 -0.622758 -0.296486
# 3       -0.304219 -0.613068 -0.584499 -0.243757 -0.266696 -0.658449 -0.299027
# 4       -0.294644 -0.615593 -0.570580 -0.247548 -0.042246 -0.642230 -0.299031
# ...           ...       ...       ...       ...       ...       ...       ...
# 2603212  0.351916  0.693827 -0.081489 -0.240643  0.008875  0.143445  0.373710
# 2603213  0.233642  0.171892  0.141842 -0.236145 -0.097772 -0.099283  0.626185
# 2603214 -0.212237 -0.280904 -0.197833 -0.245638 -0.152563 -0.125035  0.430416
# 2603215 -0.328666  0.607609 -0.180362 -0.247351 -0.143742 -0.169576  1.095596
# 2603216  0.015179  1.656635 -0.250193 -0.243560 -0.084982  0.061781  1.300252
#
#              CHGA      CDX2     ITLN1  ...      CD25    CollIV       CK7  \
# 0        0.003616 -0.377532 -0.450794  ...  0.000000  0.000000 -0.168582
# 1       -0.117573 -0.182754 -0.236199  ...  0.000000  0.000000 -0.150520
# 2       -0.091504 -0.268055 -0.355383  ...  0.000000  0.000000 -0.156116
# 3       -0.121460 -0.345381 -0.450792  ...  0.000000  0.000000 -0.136229
# 4       -0.121458 -0.377533 -0.450797  ...  0.000000  0.000000 -0.159834
# ...           ...       ...       ...  ...       ...       ...       ...
# 2603212 -0.097896  0.869830  0.579653  ...  0.077042 -0.582639  0.000000
# 2603213 -0.105545  0.092076  0.682969  ... -0.014087 -0.607179  0.000000
# 2603214 -0.105787 -0.038327 -0.173319  ... -0.085273 -0.697211  0.000000
# 2603215 -0.113879  0.370160 -0.133272  ... -0.067961 -0.715124  0.000000
# 2603216 -0.108526  1.245830 -0.063456  ...  0.012770 -0.612764  0.000000
#
#          MUC6    Xcorr   Ycorr    array       x       y   unique_region
# 0         0.0  13392.0  3387.0  B004_CL  3984.0  3387.0  B004_Ascending
# 1         0.0  14596.0  4116.0  B004_CL  5188.0  4116.0  B004_Ascending
# 2         0.0  15478.0  3146.0  B004_CL  6070.0  3146.0  B004_Ascending
# 3         0.0  16995.0  2361.0  B004_CL  7587.0  2361.0  B004_Ascending
# 4         0.0  16200.0  3891.0  B004_CL  6792.0  3891.0  B004_Ascending
# ...       ...      ...     ...      ...     ...     ...             ...
# 2603212   0.0  11101.0  2079.0    colon  1693.0  2079.0      B008_Trans
# 2603213   0.0  11093.0  2127.0    colon  1685.0  2127.0      B008_Trans
# 2603214   0.0  11172.0  2608.0    colon  1764.0  2608.0      B008_Trans
# 2603215   0.0   9825.0  5095.0    colon   417.0  5095.0      B008_Trans
# 2603216   0.0  10059.0  5855.0    colon   651.0  5855.0      B008_Trans
#
# [2603217 rows x 59 columns]

# %%
intestine_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/')
intestine_CODEX.createKfold(k=5)
intestine_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/')
intestine_CODEX.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/kfolds')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/ as labels.csv
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/intestine_CODEX/quantification/processed/kfolds
# Overwriting 'fold_1_train.csv'... and saving validation
# Overwriting 'fold_2_train.csv'... and saving validation
# Overwriting 'fold_3_train.csv'... and saving validation
# Overwriting 'fold_4_train.csv'... and saving validation
# Overwriting 'fold_5_train.csv'... and saving validation
# Validation indices updated in fold_indices.json

# %%
del intestine_CODEX

# %%
feto_maternal = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/decidua_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
feto_maternal.data
# Out:
#            CD11c      CD14      CD16     CD163      CD20     CD206       CD3  \
# 0       0.000000  0.858311  0.769537  0.826435  0.305853  0.854678  0.000000
# 1       0.000000  0.608643  0.000000  0.356172  0.000000  0.000000  0.613772
# 2       0.000000  0.821260  0.619963  0.814300  0.482688  0.728758  0.000000
# 3       0.000000  0.818859  0.596728  0.623279  0.000000  0.507723  0.000000
# 4       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...          ...       ...       ...       ...       ...       ...       ...
# 495344  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 495345  0.068865  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 495346  0.725608  0.631638  0.537892  0.686284  0.277864  0.354021  0.000000
# 495347  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 495348  0.326975  0.305322  0.107786  0.338942  0.000000  0.169412  0.000000
#
#             CD31       CD4      CD44  ...   perimeter         Point     x  \
# 0       0.000000  0.869078  0.602367  ...  113.154329  10_31742_1_2    35
# 1       0.000000  0.000000  0.632391  ...   81.633514  10_31742_1_2   629
# 2       0.000000  0.777645  0.618453  ...   78.183766  10_31742_1_2  1189
# 3       0.000000  0.786343  0.612739  ...   96.769553  10_31742_1_2  1914
# 4       0.000000  0.000000  0.122189  ...  119.047727  10_31742_1_2   322
# ...          ...       ...       ...  ...         ...           ...   ...
# 495344  0.000000  0.000000  0.409816  ...   76.183766  16_31766_3_2  1846
# 495345  0.000000  0.000000  0.000000  ...   45.384776  16_31766_3_2  1718
# 495346  0.417691  0.591745  0.570298  ...  155.982756  16_31766_3_2  1977
# 495347  0.000000  0.000000  0.095473  ...  141.053824  16_31766_3_2   431
# 495348  0.000000  0.147407  0.334885  ...  239.551299  16_31766_3_2   717
#
#            y  area_nuclear  nucleated  overlap_decidua_only  point_mean_delta  \
# 0       1146             0          0                     1          1.645576
# 1       1245           205          1                     0          1.645576
# 2        760           213          1                     1          1.645576
# 3       1151           269          1                     1          1.645576
# 4         10             0          0                     1          1.645576
# ...      ...           ...        ...                   ...               ...
# 495344  1735             0          0                     1               NaN
# 495345   796           159          1                     1               NaN
# 495346   472             0          0                     1               NaN
# 495347   749             0          0                     1               NaN
# 495348   707           281          1                     1               NaN
#
#         distance_from_artery    cell_type
# 0                 426.656771        Mac2a
# 1                        NaN        other
# 2                 328.184399        Mac2a
# 3                 286.043703        Mac2a
# 4                 505.262308        other
# ...                      ...          ...
# 495344                   NaN  Fibroblasts
# 495345                   NaN  Fibroblasts
# 495346                   NaN          NK3
# 495347                   NaN  Fibroblasts
# 495348                   NaN        EVT1a
#
# [495349 rows x 53 columns]

# %%
feto_maternal.preprocess(dropna=False, drop_columns=['point_mean_delta', 'distance_from_artery'], group_identifier_columns = 'Point')
# Out:
# Data successfully preprocessed

# %%
feto_maternal.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/')
feto_maternal.createKfold(k=5)
feto_maternal.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/')
feto_maternal.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/kfolds')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/ as labels.csv
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/feto_maternal/quantification/processed/kfolds
# Overwriting 'fold_1_train.csv'... and saving validation
# Overwriting 'fold_2_train.csv'... and saving validation
# Overwriting 'fold_3_train.csv'... and saving validation
# Overwriting 'fold_4_train.csv'... and saving validation
# Overwriting 'fold_5_train.csv'... and saving validation
# Validation indices updated in fold_indices.json

# %%
CRC_FFPE = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/CRC_FFPE_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
CRC_FFPE.data
# Out:
#               CD44       FOXP3         CD8          p53       GATA3  \
# 0         1.843591   17.398706    0.000000    59.391884   35.244526
# 1        30.284525   18.375738   74.695236   271.420136   30.313547
# 2       139.488510  249.746979   85.556976   705.369324   49.865829
# 3        20.596886   81.759758    0.000000     0.000000   34.731583
# 4        67.328728  122.195473   11.028284   325.076691   93.776245
# ...            ...         ...         ...          ...         ...
# 258380   30.748373   44.689804    0.000000   164.633865   37.099144
# 258381  613.206909  481.540497  239.230286   713.958069  246.010757
# 258382  392.992676  359.488373  276.082519  1243.198608  400.688873
# 258383  144.657471  198.371643    0.000000     0.000000  104.403664
# 258384  259.350708    0.000000  511.703155    46.236359   39.979027
#
#                CD45        T-bet  beta-catenin    HLA-DR       PD-L1  ...  \
# 0          0.000000    45.537239    258.346375  0.000000    7.834526  ...
# 1          0.000000     8.821254    668.978577  0.000000   80.639305  ...
# 2          8.435891   179.875778    480.811737  3.066591  172.340301  ...
# 3          0.000000   122.186234    145.830063  0.000000    5.521088  ...
# 4          0.000000   323.319305    987.071655  0.000000   63.922062  ...
# ...             ...          ...           ...       ...         ...  ...
# 258380   770.756287     0.000000    620.035217  0.000000    0.000000  ...
# 258381  2236.093018   549.120544    972.123901  2.378212  273.330841  ...
# 258382  5450.664551  1104.000000   1674.244507  0.353912  288.512848  ...
# 258383  3242.847900   518.949768   1027.370483  1.378499  120.991173  ...
# 258384  1880.674072     0.000000    523.930664  0.000000    0.000000  ...
#
#              MMP9         CD71        CD57       MMP12        DRAQ5   size  \
# 0        0.000000   655.881592   27.169783   36.131023  2011.402222  10120
# 1        0.000000   478.416260  160.619858   39.138241  3221.254883    861
# 2       17.974144   387.765259   72.910377    2.523008  5228.323730   6206
# 3        0.000000   612.506958   12.255139   30.254667  1259.016846   6320
# 4        0.000000  2661.427979   84.200500  186.074799  8041.375000   1591
# ...           ...          ...         ...         ...          ...    ...
# 258380   0.000000   897.826416   13.697555    2.403872  2098.054688   6646
# 258381   4.792668   338.211517   42.180298   13.714349  3702.538330   2770
# 258382   0.235941  1480.583740   73.265282   40.589241  5737.778320   1636
# 258383   0.920707  2417.131348   64.942406   29.051401  5763.093262   3435
# 258384   0.000000  1318.838013   14.700948    8.482681  1156.453857   7048
#
#            x    y  File Name     cell_type
# 0         77  589   reg001_A  granulocytes
# 1        106  826   reg001_A  granulocytes
# 2        107  545   reg001_A  granulocytes
# 3         98  564   reg001_A  granulocytes
# 4        217  329   reg001_A  granulocytes
# ...      ...  ...        ...           ...
# 258380  1629  717   reg057_B  CD3+ T cells
# 258381   741  878   reg059_A  CD3+ T cells
# 258382   668  551   reg062_A  CD3+ T cells
# 258383   868  162   reg067_A  CD3+ T cells
# 258384   382  450   reg069_B  CD3+ T cells
#
# [258385 rows x 63 columns]

# %%
CRC_FFPE.preprocess(dropna=False, group_identifier_columns = 'File Name')
# Out:
# Data successfully preprocessed

# %%
CRC_FFPE.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/')
CRC_FFPE.createKfold(k=5)
CRC_FFPE.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/')
CRC_FFPE.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/kfolds')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/ as labels.csv
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/CRC_FFPE/quantification/processed/kfolds
# Overwriting 'fold_1_train.csv'... and saving validation
# Overwriting 'fold_2_train.csv'... and saving validation
# Overwriting 'fold_3_train.csv'... and saving validation
# Overwriting 'fold_4_train.csv'... and saving validation
# Overwriting 'fold_5_train.csv'... and saving validation
# Validation indices updated in fold_indices.json

# %%
be_tonsil = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/BE_Tonsil_l3_dryad_cleaned.csv', random_state = rs)
tonsil_training = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/B004_training_dryad_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully
# DataSetHandler initialized successfully

# %%
print(be_tonsil.data.isna().sum().sum())
tonsil_training.data.isna().sum().sum()
# Out:
# 0
# 0

# %%
be_tonsil.data
# Out:
#             CHGA      PDL1      CD56       CK7     FoxP3      CD21      MUC1  \
# 0      -0.015838 -0.262392 -0.328807 -0.030104 -0.169786 -0.195315 -0.144450
# 1      -0.063117 -0.075990  1.852914 -0.030104 -0.169786  2.408519 -0.144450
# 2      -0.070705 -0.262392 -0.362758 -0.030104 -0.169786  0.281066 -0.144449
# 3      -0.061208 -0.186271 -0.074156 -0.030104 -0.169786 -0.078391 -0.144447
# 4      -0.070660 -0.123091  0.006811 -0.030104  0.100844  0.054867 -0.144450
# ...          ...       ...       ...       ...       ...       ...       ...
# 219921 -0.070250 -0.262392  0.637652 -0.030104 -0.169786 -0.174148 -0.144450
# 219922 -0.058163 -0.160154  0.202644 -0.030104 -0.169786 -0.219187 -0.144450
# 219923 -0.067054 -0.214624  0.057478 -0.004263 -0.166512 -0.155890  0.100125
# 219924 -0.013725 -0.138051 -0.057624 -0.030104 -0.169778 -0.309653 -0.121936
# 219925 -0.001454 -0.262392  0.408094 -0.030104 -0.169786 -0.238076 -0.144450
#
#              PD1     CD11b       CD4  ...  Arginase1      CD73     CD206  \
# 0      -0.314147 -0.306023 -0.681588  ...   0.183429 -0.471492  0.368175
# 1       1.413897  1.150271 -0.499367  ...   3.152803 -0.460310  0.406059
# 2      -0.270863 -0.306020 -0.681588  ...  -0.300006  0.798789 -0.238657
# 3      -0.088802  0.294455 -0.681588  ...   1.068848 -0.256614 -0.230057
# 4      -0.046886  2.337389 -0.588588  ...   3.108413 -0.451207 -0.165934
# ...          ...       ...       ...  ...        ...       ...       ...
# 219921  0.044370 -0.306023 -0.572092  ...  -0.263463 -0.367291 -0.110060
# 219922 -0.201268 -0.306023 -0.619760  ...  -0.193195  0.916953  3.677105
# 219923 -0.122829 -0.301920 -0.255616  ...  -0.041300 -0.163893 -0.192927
# 219924 -0.334723 -0.306023  0.712992  ...  -0.651138 -0.471492 -0.249438
# 219925 -0.264429 -0.306023 -0.500370  ...  -0.588339 -0.471240  0.179548
#
#             MUC6      COX2      MMP9       x       y         sample_name  \
# 0      -0.137850  0.148542 -0.161118   394.0  3516.0              tonsil
# 1       0.247144  0.549028 -0.114117  5469.0  2463.0              tonsil
# 2      -0.137942 -0.167777 -0.161118  2506.0  4793.0              tonsil
# 3      -0.130576 -0.069935 -0.161118  8933.0   796.0              tonsil
# 4      -0.126458  0.048613 -0.153662  4793.0  1885.0              tonsil
# ...          ...       ...       ...     ...     ...                 ...
# 219921 -0.137930 -0.096468 -0.161118  4373.0  1739.0  Barretts Esophagus
# 219922 -0.137942 -0.163933 -0.161118  4831.0  2782.0  Barretts Esophagus
# 219923 -0.072235 -0.137067 -0.140883  1592.0  8542.0  Barretts Esophagus
# 219924 -0.137942 -0.171432 -0.161118  3236.0   238.0  Barretts Esophagus
# 219925 -0.137942 -0.165469 -0.161118  4453.0   396.0  Barretts Esophagus
#
#           cell_type
# 0            Innate
# 1            Innate
# 2              PDPN
# 3       Endothelial
# 4            Innate
# ...             ...
# 219921       Innate
# 219922       Innate
# 219923       Innate
# 219924       Innate
# 219925       Innate
#
# [219926 rows x 48 columns]

# %%
tonsil_training.data
# Out:
#             MUC2      SOX9      MUC1      CD31   Synapto     CD49f      CD15  \
# 0      -0.241565  0.538240 -0.145700 -0.254499 -0.312923 -0.440809 -0.083480
# 1      -0.231567  1.053268  0.015944 -0.248268 -0.314157  0.461514 -0.094145
# 2       0.207531  0.526999 -0.057481 -0.249034 -0.325943  0.033951 -0.094142
# 3      -0.076672 -0.420316 -0.051284 -0.252876 -0.302395  1.100307 -0.093069
# 4      -0.235334  0.376148  0.025601 -0.251348 -0.316774 -0.074358 -0.094141
# ...          ...       ...       ...       ...       ...       ...       ...
# 248280 -0.301417 -0.480617 -0.485732 -0.247548 -0.075596 -0.601329 -0.296372
# 248281 -0.302128 -0.469591 -0.486481 -0.201661 -0.252108 -0.632735 -0.291958
# 248282 -0.300624 -0.505039 -0.481408 -0.206155 -0.257355 -0.611439 -0.297305
# 248283 -0.241006 -0.217832 -0.350860 -0.235930  0.407688 -0.585294 -0.297135
# 248284 -0.304218 -0.570549 -0.477373 -0.247548 -0.256739 -0.609668 -0.284186
#
#             CHGA      CDX2     ITLN1  ...      Ki67     CD49a     CD163  \
# 0      -0.073498 -0.182247 -0.395115  ... -0.270736 -0.574298 -0.274995
# 1      -0.087275  0.246550 -0.292916  ...  0.161482 -0.484751 -0.265804
# 2      -0.086326 -0.005325 -0.288484  ...  0.360991 -0.517455 -0.274345
# 3      -0.081959  0.005021 -0.355146  ...  0.137150 -0.460114 -0.274582
# 4      -0.080630 -0.029893 -0.342737  ... -0.041417 -0.519680 -0.273687
# ...          ...       ...       ...  ...       ...       ...       ...
# 248280 -0.121456 -0.298825 -0.407754  ... -0.275793 -0.448915 -0.329448
# 248281 -0.089449 -0.345515 -0.399732  ... -0.298807 -0.648830 -0.263899
# 248282 -0.096474 -0.338581 -0.430508  ... -0.290010 -0.616562 -0.280333
# 248283 -0.069509 -0.099756 -0.256268  ...  0.012376 -0.387270 -0.120730
# 248284  0.213849 -0.260464 -0.427174  ... -0.085752 -0.460000 -0.309882
#
#            CD161       x       y  tissue  donor   unique_region   cell_type
# 0      -0.083926  1253.0   886.0      SB   B004  reg001_SB_B004  Enterocyte
# 1      -0.052165  1259.0   874.0      SB   B004  reg001_SB_B004  Enterocyte
# 2      -0.062414  1287.0   845.0      SB   B004  reg001_SB_B004  Enterocyte
# 3      -0.063367  1294.0   964.0      SB   B004  reg001_SB_B004  Enterocyte
# 4      -0.047192  1307.0   841.0      SB   B004  reg001_SB_B004  Enterocyte
# ...          ...     ...     ...     ...    ...             ...         ...
# 248280 -0.110390  8672.0  7054.0      CL   B004  reg004_CL_B004      Plasma
# 248281 -0.104248  8727.0  6182.0      CL   B004  reg004_CL_B004      Plasma
# 248282 -0.082285  9031.0  6452.0      CL   B004  reg004_CL_B004      Plasma
# 248283 -0.058423  8335.0  7248.0      CL   B004  reg004_CL_B004      Plasma
# 248284  0.251603  3156.0  1849.0      CL   B004  reg001_CL_B004  Enterocyte
#
# [248285 rows x 54 columns]

# %%
be_tonsil.preprocess(dropna=False)
tonsil_training.preprocess(dropna=False)
# Out:
# Data successfully preprocessed
# Data successfully preprocessed

# %%
tonsil_training.X
# Out:
#             MUC2      SOX9      MUC1      CD31   Synapto     CD49f      CD15  \
# 0      -0.241565  0.538240 -0.145700 -0.254499 -0.312923 -0.440809 -0.083480
# 1      -0.231567  1.053268  0.015944 -0.248268 -0.314157  0.461514 -0.094145
# 2       0.207531  0.526999 -0.057481 -0.249034 -0.325943  0.033951 -0.094142
# 3      -0.076672 -0.420316 -0.051284 -0.252876 -0.302395  1.100307 -0.093069
# 4      -0.235334  0.376148  0.025601 -0.251348 -0.316774 -0.074358 -0.094141
# ...          ...       ...       ...       ...       ...       ...       ...
# 248280 -0.301417 -0.480617 -0.485732 -0.247548 -0.075596 -0.601329 -0.296372
# 248281 -0.302128 -0.469591 -0.486481 -0.201661 -0.252108 -0.632735 -0.291958
# 248282 -0.300624 -0.505039 -0.481408 -0.206155 -0.257355 -0.611439 -0.297305
# 248283 -0.241006 -0.217832 -0.350860 -0.235930  0.407688 -0.585294 -0.297135
# 248284 -0.304218 -0.570549 -0.477373 -0.247548 -0.256739 -0.609668 -0.284186
#
#             CHGA      CDX2     ITLN1  ...      CD69      Ki67     CD49a  \
# 0      -0.073498 -0.182247 -0.395115  ... -0.255296 -0.270736 -0.574298
# 1      -0.087275  0.246550 -0.292916  ... -0.246320  0.161482 -0.484751
# 2      -0.086326 -0.005325 -0.288484  ... -0.250225  0.360991 -0.517455
# 3      -0.081959  0.005021 -0.355146  ... -0.129018  0.137150 -0.460114
# 4      -0.080630 -0.029893 -0.342737  ... -0.247002 -0.041417 -0.519680
# ...          ...       ...       ...  ...       ...       ...       ...
# 248280 -0.121456 -0.298825 -0.407754  ... -0.127508 -0.275793 -0.448915
# 248281 -0.089449 -0.345515 -0.399732  ... -0.275998 -0.298807 -0.648830
# 248282 -0.096474 -0.338581 -0.430508  ... -0.298619 -0.290010 -0.616562
# 248283 -0.069509 -0.099756 -0.256268  ... -0.287577  0.012376 -0.387270
# 248284  0.213849 -0.260464 -0.427174  ... -0.384765 -0.085752 -0.460000
#
#            CD163     CD161       x       y  tissue  donor   unique_region
# 0      -0.274995 -0.083926  1253.0   886.0      SB   B004  reg001_SB_B004
# 1      -0.265804 -0.052165  1259.0   874.0      SB   B004  reg001_SB_B004
# 2      -0.274345 -0.062414  1287.0   845.0      SB   B004  reg001_SB_B004
# 3      -0.274582 -0.063367  1294.0   964.0      SB   B004  reg001_SB_B004
# 4      -0.273687 -0.047192  1307.0   841.0      SB   B004  reg001_SB_B004
# ...          ...       ...     ...     ...     ...    ...             ...
# 248280 -0.329448 -0.110390  8672.0  7054.0      CL   B004  reg004_CL_B004
# 248281 -0.263899 -0.104248  8727.0  6182.0      CL   B004  reg004_CL_B004
# 248282 -0.280333 -0.082285  9031.0  6452.0      CL   B004  reg004_CL_B004
# 248283 -0.120730 -0.058423  8335.0  7248.0      CL   B004  reg004_CL_B004
# 248284 -0.309882  0.251603  3156.0  1849.0      CL   B004  reg001_CL_B004
#
# [248285 rows x 53 columns]

# %%
be_tonsil.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/')
tonsil_training.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/')
be_tonsil.createKfold(k=5)
tonsil_training.createKfold(k=5)
be_tonsil.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/')
tonsil_training.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/')
be_tonsil.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/kfolds')
tonsil_training.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/kfolds')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/ as labels.csv
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/ as labels.csv
# 5 folds created. To save the folds, call save_folds method.
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/BE_tonsil/processed/kfolds
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/BA_CODEX/quantification/tonsil_training/processed/kfolds
# Overwriting 'fold_1_train.csv'... and saving validation
# Overwriting 'fold_2_train.csv'... and saving validation
# Overwriting 'fold_3_train.csv'... and saving validation
# Overwriting 'fold_4_train.csv'... and saving validation
# Overwriting 'fold_5_train.csv'... and saving validation
# Validation indices updated in fold_indices.json
# Overwriting 'fold_1_train.csv'... and saving validation
# Overwriting 'fold_2_train.csv'... and saving validation
# Overwriting 'fold_3_train.csv'... and saving validation
# Overwriting 'fold_4_train.csv'... and saving validation
# Overwriting 'fold_5_train.csv'... and saving validation
# Validation indices updated in fold_indices.json

# %%
del be_tonsil, tonsil_training, feto_maternal, CRC_FFPE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 del be_tonsil, tonsil_training, feto_maternal, CRC_FFPE
#
# NameError: name 'feto_maternal' is not defined

# %%
aml = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/AML_cleaned.csv', random_state = rs)
bm = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/normal_bone_marrow_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully
# DataSetHandler initialized successfully

# %%
aml.data.isna().sum().sum()
# Out:
# 0

# %%
bm.data.isna().sum().sum()
# Out:
# 0

# %%
bm.data
# Out:
#             CD19      ASMA       CD4      CD44      CD71     CD271      CD90  \
# 0       0.635958  0.471304  0.341072  0.052372  0.519640  0.377627  0.102366
# 1       0.234598  0.482261  0.605216  0.185311  0.761581  0.390987  0.035872
# 2       0.222422  0.498447  0.636258  0.250054  0.957736  0.482735  0.579884
# 3       0.333615  0.462209  0.594836  0.094583  0.493624  0.350734  0.041616
# 4       0.413143  0.458818  0.639790  0.187459  0.532472  0.423685  0.153343
# ...          ...       ...       ...       ...       ...       ...       ...
# 886520  0.730957  0.536065  1.018522  0.631627  0.829153  0.646345  0.351415
# 886521  0.733641  0.530946  0.509524  0.337657  0.600458  0.665746  0.618660
# 886522  0.575626  0.631906  0.681686  0.901300  0.978607  0.629994  0.335544
# 886523  0.779029  0.592717  0.745327  0.788631  0.709830  1.211243  2.088245
# 886524  0.940160  0.462133  0.865623  1.083292  0.551655  0.597003  0.336778
#
#              VIM      CD68    SPINK2  ...        DAPI     ADIPOQ       Ki67  \
# 0       0.356934  0.516020  0.367927  ...   40.430894  21.211382  18.707317
# 1       0.295122  0.480176  0.043507  ...   24.685950  15.603306   2.132231
# 2       0.262495  0.368985  0.348405  ...   20.971831  12.225352   3.197183
# 3       0.396020  0.397740  0.190946  ...   27.000000  15.600000   2.507692
# 4       0.228610  0.494665  0.380412  ...   36.611765  17.223529   1.964706
# ...          ...       ...       ...  ...         ...        ...        ...
# 886520  0.518416  0.845883  0.866838  ...  102.780702  20.122807  29.973684
# 886521  0.563854  0.829757  0.623655  ...   56.973333  17.353333   9.440000
# 886522  0.480129  0.670313  0.543252  ...   71.858974  27.461538  17.833333
# 886523  0.728595  0.866948  1.702557  ...  116.252475  31.103960  22.158416
# 886524  0.916345  0.775945  0.755586  ...   83.102804  17.065421   4.579439
#
#              CD56  NAKATPASE  Size             x             y  \
# 0       21.666667  20.788618   123  13004.252033    104.243902
# 1       16.983471  18.975207   121  12980.925620    136.413223
# 2       10.323944  23.845070    71  12935.408451    153.746479
# 3       14.415385  18.276923    65  12875.461538    170.600000
# 4       17.229412  18.976471   170  12922.470588    173.664706
# ...           ...        ...   ...           ...           ...
# 886520   4.061404  46.982456   114  10986.201754  13397.842105
# 886521   4.926667  35.720000   150  12282.680000  13398.993333
# 886522   4.521368  47.179487   234  11625.491453  13399.905983
# 886523   5.351485  50.559406   202   7847.410891  13399.772277
# 886524   4.873832  32.313084   214  10670.004673  13399.766355
#
#                          orig.ident                 cell_type
# 0       SB67_NBM27_H10_CODEX_Mesmer                  Artifact
# 1       SB67_NBM27_H10_CODEX_Mesmer                  Artifact
# 2       SB67_NBM27_H10_CODEX_Mesmer              Undetermined
# 3       SB67_NBM27_H10_CODEX_Mesmer  Early Myeloid Progenitor
# 4       SB67_NBM27_H10_CODEX_Mesmer                  Artifact
# ...                             ...                       ...
# 886520  SB67_NBM39_H41_CODEX_Mesmer                 Erythroid
# 886521  SB67_NBM39_H41_CODEX_Mesmer      Intermediate Myeloid
# 886522  SB67_NBM39_H41_CODEX_Mesmer                 Erythroid
# 886523  SB67_NBM39_H41_CODEX_Mesmer           Autofluorescent
# 886524  SB67_NBM39_H41_CODEX_Mesmer               CD8+ T-Cell
#
# [886525 rows x 59 columns]

# %%
aml.preprocess(dropna=False, group_identifier_columns = 'orig.ident')
bm.preprocess(dropna=False, group_identifier_columns = 'orig.ident')
# Out:
# Data successfully preprocessed
# Data successfully preprocessed

# %%
aml.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/')#bm.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/')
aml.createKfold(k=5)
bm.createKfold(k=5)
aml.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/')
bm.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/')
aml.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/kfolds')
bm.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/kfolds')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/ as labels.csv
# 5 folds created. To save the folds, call save_folds method.
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/AML/processed/kfolds
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/AML_bone_marrow/quantification/healthy_BM/processed/kfolds
# Overwriting 'fold_1_train.csv'... and saving validation
# Overwriting 'fold_2_train.csv'... and saving validation
# Overwriting 'fold_3_train.csv'... and saving validation
# Overwriting 'fold_4_train.csv'... and saving validation
# Overwriting 'fold_5_train.csv'... and saving validation
# Validation indices updated in fold_indices.json
# Overwriting 'fold_1_train.csv'... and saving validation
# Overwriting 'fold_2_train.csv'... and saving validation
# Overwriting 'fold_3_train.csv'... and saving validation
# Overwriting 'fold_4_train.csv'... and saving validation
# Overwriting 'fold_5_train.csv'... and saving validation
# Validation indices updated in fold_indices.json

# %%
MRL_CODEX = DataSetHandler(path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/Suppl.Table2.CODEX_paper_MRLdatasetexpression_cleaned.csv', random_state = rs)
# Out:
# DataSetHandler initialized successfully

# %%
MRL_CODEX.data.isna().sum().sum()
# Out:
# 0

# %%
MRL_CODEX.data
# Out:
#                CD45         Ly6C         TCR        Ly6G         CD19  \
# 0       1577.675415  -154.301758  130.692184   -4.168493   560.691345
# 1       1017.838440   -93.069397  144.076584   40.010998   885.595520
# 2       5978.459961  -330.099365  139.631744  -82.840302  1747.897583
# 3       6119.109375   -54.384808 -768.871704   25.625927  1065.311890
# 4       6272.474609  -235.512405   74.058075 -101.729919  1186.295044
# ...             ...          ...         ...         ...          ...
# 734096  -688.832153  -219.017471  260.814728 -102.244308   191.481277
# 734097  -418.201904  -349.080231 -212.614212 -602.782959  -114.562439
# 734098   521.979492  1831.827148  244.709000  118.634224   778.191040
# 734099  -944.904663  -127.192131 -309.472839   72.905830   373.572662
# 734100   763.462097   275.175629 -212.799255  243.105194   583.138489
#
#               CD169        CD106          CD3       CD1632         CD8a  ...  \
# 0       -504.231476   854.670105  -631.294189   385.935242   242.400131  ...
# 1       -391.357544    62.764454  -474.201172  -469.634583   482.660309  ...
# 2       -395.508820   954.326782 -1026.204468  3744.718262  1287.204956  ...
# 3       -485.535431   538.404175  -611.836426   865.842590   554.589905  ...
# 4       -782.744995  1261.625366  -915.565552  1361.536011   258.848846  ...
# ...             ...          ...          ...          ...          ...  ...
# 734096  -780.639587  -386.735748 -1022.373962  -136.550278  -667.158691  ...
# 734097 -1160.290161  -889.838257 -1013.993713  -917.420166  -667.360107  ...
# 734098   151.496323  1562.585083   526.572327   769.504578   630.214294  ...
# 734099  -287.188904  -357.778961  -386.898590   -20.499031  2619.047852  ...
# 734100   548.872070  1863.510986   511.723022  1332.292480  1076.271362  ...
#
#                B220        ERTR7        CD35      CD2135         CD44  \
# 0        457.675629   840.192688  120.959267   -1.224402   422.408691
# 1       1217.684692   682.790100   53.276588   20.090719   448.701660
# 2        666.266418   753.930969  601.395996  161.183090  2229.804443
# 3       2261.370361   249.342300  244.572174  135.403366   665.720459
# 4       1058.446533  -267.946808  211.492844  -41.061123  2065.742676
# ...             ...          ...         ...         ...          ...
# 734096  -358.940735   172.902756  194.764572   56.864479  -164.587204
# 734097  3346.783691  2857.673828  869.343933  304.062866   584.659729
# 734098   849.758118   958.845459  148.190170  138.270584   967.803772
# 734099   442.771057   -48.994541  396.196289  163.886475  -164.626266
# 734100   642.832092  1129.472900  144.636276  152.919556  1665.058594
#
#              NKp46        MHCII     x    y         cell_type
# 0       515.130066  6712.812988    10   70  CD11c(+) B cells
# 1       171.880310  2024.678711  1000  294  CD11c(+) B cells
# 2       512.220764  8647.193359  1003  107  CD11c(+) B cells
# 3       351.108246  4838.463379  1003  113  CD11c(+) B cells
# 4       259.003235  5092.891602  1003  148  CD11c(+) B cells
# ...            ...          ...   ...  ...               ...
# 734096   -9.616314   958.904358   955  482    CD4(+)MHCII(+)
# 734097  788.070068   756.565369   960  853    CD4(+)MHCII(+)
# 734098  760.188660   146.096573    97  517    CD4(+)MHCII(+)
# 734099   31.346064   617.386902   975  149    CD4(+)MHCII(+)
# 734100  328.518311   133.358414    98  871    CD4(+)MHCII(+)
#
# [734101 rows x 33 columns]

# %%
MRL_CODEX.preprocess(dropna=False)
# Out:
# Data successfully preprocessed

# %%
MRL_CODEX.save_labels('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/')
MRL_CODEX.createKfold(k=5)
MRL_CODEX.save_folds('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/')
MRL_CODEX.create_validation_set_from_fold(save_path='/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/kfolds')
# Out:
# Labels saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/ as labels.csv
# 5 folds created. To save the folds, call save_folds method.
# Folds saved in: /Volumes/Lukas_SSD/phenotyping_benchmark/datasets/MRL_CODEX/quantification/processed/kfolds
# Overwriting 'fold_1_train.csv'... and saving validation
# Overwriting 'fold_2_train.csv'... and saving validation
# Overwriting 'fold_3_train.csv'... and saving validation
# Overwriting 'fold_4_train.csv'... and saving validation
# Overwriting 'fold_5_train.csv'... and saving validation
# Validation indices updated in fold_indices.json
