# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/cHL_2_MIBI/quantification/processed/kfolds_StratifiedGroupKFold/fold_1_train.csv')
val = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/cHL_2_MIBI/quantification/processed/kfolds_StratifiedGroupKFold/fold_1_validation.csv')
test = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/cHL_2_MIBI/quantification/processed/kfolds_StratifiedGroupKFold/fold_1_test.csv')

# %%
train['encoded_phenotype'].value_counts()
# Out:
# encoded_phenotype
# 1     39666
# 7     19670
# 10    14076
# 0     13768
# 9     13291
# 11    12802
# 4     12503
# 2      9060
# 3      5287
# 5      4129
# 6      3342
# 8      3156
# Name: count, dtype: int64

# %%
train['encoded_phenotype'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='encoded_phenotype'>

# %%
test['encoded_phenotype'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='encoded_phenotype'>

# %%
test['sample_id'].unique()
# Out:
# array(['1.csv', '2.csv', '6.csv'], dtype=object)

# %%
train['sample_id'].unique()
# Out:
# array(['5.csv', '4.csv', '3.csv'], dtype=object)

# %%
train = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/cHL_2_MIBI/quantification/processed/kfolds_GroupShuffleSplit/fold_1_train.csv')
val = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/cHL_2_MIBI/quantification/processed/kfolds_GroupShuffleSplit/fold_1_validation.csv')
test = pd.read_csv('/Volumes/Lukas_SSD/phenotyping_benchmark/datasets/cHL_2_MIBI/quantification/processed/kfolds_GroupShuffleSplit/fold_1_test.csv')

# %%
train['encoded_phenotype'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='encoded_phenotype'>

# %%
test['encoded_phenotype'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='encoded_phenotype'>
